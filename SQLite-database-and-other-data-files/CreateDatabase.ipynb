# %% [markdown]
# ### Creating a public use database named "ribi_during_covid."
# ### Author: Alexander Janus
# ### Created: July 2, 2021
# ### Modified: July 2, 2021

# %%
import sqlite3

# %%
import numpy as np

# %%
import pandas as pd

# %%
import pyreadstat

# %%
connection = sqlite3.connect(r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\CreatedDatabase\ribi_during_covid")

# %%
cursor = connection.cursor()

# %% [markdown]
# ### Creating table ClubLvl

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS ClubLvl\
(ClubID                INTEGER,\
ClubNameR              NVARCHAR,\
DistID                 INTEGER,\
DistName               NVARCHAR,\
ClubSample             INTEGER,\
ClubWeight             DECIMAL(18,18),\
/*** TABLE CONSTRAINTS ***/ \
PRIMARY KEY (ClubID))")

# %% [markdown]
# ### Creating table IndvLvl

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS IndvLvl\
(ClubID                INTEGER,\
IndvID                 INTEGER,\
\
\
\
/*** GEOGRAPHY ***/ \
Country                NVARCHAR       NOT NULL CONSTRAINT CHK_Country CHECK (Country IN ('England', 'Scotland','Wales', 'Northern Ireland')),\
/*** Null vales are not allowed, because Country is used to define the analytical sample. ***/ \
PostCode               NVARCHAR,\
\
\
\
/*** DEMOGRAPHICS ***/ \
Gender                 NVARCHAR       CONSTRAINT CHK_Gender CHECK (Gender IN ('Female', 'Male','Other:')),\
/*** The 'other:' responses to this question appear to be errors. ***/ \
Age                    NVARCHAR       CONSTRAINT CHK_Age CHECK (Age IN ('18-54 years', '55-64 years', '65-74 years', '75 or more years')),\
BirthYear              INTEGER        CONSTRAINT CHK_BirthYear CHECK (BirthYear >= 1920 AND BirthYear <=2001),\
BirthMonth             NVARCHAR       CONSTRAINT CHK_BirthMonth CHECK (BirthMonth IN \
                                            ('January', 'February', 'March', 'April', 'May', 'June', \
                                             'July', 'August', 'September', 'October', 'November', 'December')),\
ActivityStatus         NVARCHAR       CONSTRAINT CHK_ActivityStatus CHECK (ActivityStatus IN \
                                            ('Employed', 'Self-employed', 'Unemployed', 'Retired', 'Permanently sick or disabled', \
                                             'Looking after home or family', 'In education or training', 'Other')),\
ResidentialStatus      NVARCHAR       CONSTRAINT CHK_ResidentialStatus CHECK (ResidentialStatus IN ('A private or family household', 'A communal establishment')),\
OwnershipStatus        NVARCHAR       CONSTRAINT CHK_OwnershipStatus CHECK (OwnershipStatus IN \
                                            ('Owned outright', 'Still being bought', 'Privately rented', \
                                             'Socially rented', 'Other')),\
LiveAlone              NVARCHAR       CONSTRAINT CHK_LiveAlone CHECK (LiveAlone IN ('Yes', 'No, I live with at least one other person')),\
Ethnicity              NVARCHAR       CONSTRAINT CHK_Ethnicity CHECK (Ethnicity IN \
                                            (/*** White ***/'English', 'Welsh', 'Scottish', 'Northern Irish', 'British', 'Irish', 'Traveller',\
                                             'Polish', 'Any other White ethnic group',\
                                             /*** Mixed or Multiple ethnic groups ***/'Any Mixed or Multiple ethnic groups',\
                                             /*** Asian or Asian British ***/'Pakistani or Pakistani British', 'Indian or Indian British',\
                                             'Bangladeshi or Bangladeshi British', 'Chinese or Chinese British', 'Any other Asian',\
                                             /*** African ***/'African or African British', 'Any other African',\
                                             /*** Carribean or Black ***/'Caribbean or Caribbean British', 'Black or Black British',\
                                             'Any other Caribbean or Black',\
                                             /*** Other ethnic group ***/'Arab or Arab British', 'Any other ethnic group')),\
Education              NVARCHAR      CONSTRAINT CHK_Education CHECK (Education IN \
                                             ('No formal schooling', 'Some primary', 'Primary or equivalent', \
                                              'O level/O grade or equivalent', 'Highers or equivalent', 'Sixth year studies or equivalent', \
                                              'HNC/HND or equivalent', 'First degree', 'Postgraduate/higher degree')),\
Religion               NVARCHAR       CONSTRAINT CHK_Religion CHECK (Religion IN \
                                            ('Protestant', 'Catholic', 'Other Christian', 'Muslim', \
                                             'Jewish', 'Other Non-Christian Religion', 'No religion/Atheist/Agnostic')),\
\
\
\
/*** PERSONAL CHALLENGES ***/ \
PersonalChallenges     TEXT, \
\
\
\
/*** SOCIAL RELATIONSHIPS - MARITAL STATUS ***/ \
MaritalStat            NVARCHAR       CONSTRAINT CHK_MaritalStat CHECK (MaritalStat IN \
                                            ('Married', 'Living with a partner as if married', 'Single', \
                                             'Separated', 'Divorced', 'Widowed', 'Civil Partnership')),\
\
\
\
/*** SOCIAL RELATIONSHIPS - OTHER ***/ \
ChildNum               NVARCHAR       CONSTRAINT CHK_ChildNum CHECK (ChildNum IN ('None', '1', '2', '3', '4', '5 or more')),\
ChildCoResNum_1        NVARCHAR       CONSTRAINT CHK_ChildCoResNum_1 CHECK (ChildCoResNum_1 IN ('No', 'Yes')),\
ChildCoResNum_2        NVARCHAR       CONSTRAINT CHK_ChildCoResNum_2 CHECK (ChildCoResNum_2 IN ('None', '1', '2')),\
ChildCoResNum_3        NVARCHAR       CONSTRAINT CHK_ChildCoResNum_3 CHECK (ChildCoResNum_3 IN ('None', '1', '2', '3')),\
ChildCoResNum_4        NVARCHAR       CONSTRAINT CHK_ChildCoResNum_4 CHECK (ChildCoResNum_4 IN ('None', '1', '2', '3', '4')),\
ChildCoResNum_5        NVARCHAR       CONSTRAINT CHK_ChildCoResNum_5 CHECK (ChildCoResNum_5 IN ('None', '1', '2', '3', '4', '5 or more')),\
SibsNum                NVARCHAR       CONSTRAINT CHK_SibsNum CHECK (SibsNum IN ('0', '1', '2', '3', '4 or more')),\
HasOthFamily           NVARCHAR       CONSTRAINT CHK_HasOthFamily CHECK (HasOthFamily IN ('Yes', 'No')),\
HasFriends             NVARCHAR       CONSTRAINT CHK_HasFriends CHECK (HasFriends IN ('Yes', 'No')),\
\
\
\
/*** Social Contact ***/ \
ContactInPerson_Child       NVARCHAR       CONSTRAINT CHK_ContactInPerson_Child CHECK (ContactInPerson_Child IN ('Yes', 'No')),\
ContactPhone_Child          NVARCHAR       CONSTRAINT CHK_ContactPhone_Child CHECK (ContactPhone_Child IN ('Yes', 'No')),\
ContactEmail_Child          NVARCHAR       CONSTRAINT CHK_ContactEmail_Child CHECK (ContactEmail_Child IN ('Yes', 'No')),\
ContactText_Child           NVARCHAR       CONSTRAINT CHK_ContactText_Child CHECK (ContactText_Child IN ('Yes', 'No')),\
ContactVideo_Child          NVARCHAR       CONSTRAINT CHK_ContactVideo_Child CHECK (ContactVideo_Child IN ('Yes', 'No')),\
ContactSocMedia_Child       NVARCHAR       CONSTRAINT CHK_ContactSocMedia_Child CHECK (ContactSocMedia_Child IN ('Yes', 'No')),\
ChangeContact_Child         NVARCHAR       CONSTRAINT CHK_ChangeContact_Child CHECK (ChangeContact_Child IN ('Remained about the same', 'Increased', 'Decreased')),\
ChangeInPerson_Child        NVARCHAR       CONSTRAINT CHK_ChangeInPerson_Child CHECK (ChangeInPerson_Child IN ('Remained about the same', 'Increased', 'Decreased')),\
\
ContactInPerson_Sibs        NVARCHAR       CONSTRAINT CHK_ContactInPerson_Sibs CHECK (ContactInPerson_Sibs IN ('Yes', 'No')),\
ContactPhone_Sibs           NVARCHAR       CONSTRAINT CHK_ContactPhone_Sibs CHECK (ContactPhone_Sibs IN ('Yes', 'No')),\
ContactEmail_Sibs           NVARCHAR       CONSTRAINT CHK_ContactEmail_Sibs CHECK (ContactEmail_Sibs IN ('Yes', 'No')),\
ContactText_Sibs            NVARCHAR       CONSTRAINT CHK_ContactText_Sibs CHECK (ContactText_Sibs IN ('Yes', 'No')),\
ContactVideo_Sibs           NVARCHAR       CONSTRAINT CHK_ContactVideo_Sibs CHECK (ContactVideo_Sibs IN ('Yes', 'No')),\
ContactSocMedia_Sibs        NVARCHAR       CONSTRAINT CHK_ContactSocMedia_Sibs CHECK (ContactSocMedia_Sibs IN ('Yes', 'No')),\
ChangeContact_Sibs          NVARCHAR       CONSTRAINT CHK_ChangeContact_Sibs CHECK (ChangeContact_Sibs IN ('Remained about the same', 'Increased', 'Decreased')),\
ChangeInPerson_Sibs         NVARCHAR       CONSTRAINT CHK_ChangeInPerson_Sibs CHECK (ChangeInPerson_Sibs IN ('Remained about the same', 'Increased', 'Decreased')),\
\
ContactInPerson_OthFamily   NVARCHAR       CONSTRAINT CHK_ContactInPerson_OthFamily CHECK (ContactInPerson_OthFamily IN ('Yes', 'No')),\
ContactPhone_OthFamily      NVARCHAR       CONSTRAINT CHK_ContactPhone_OthFamily CHECK (ContactPhone_OthFamily IN ('Yes', 'No')),\
ContactEmail_OthFamily      NVARCHAR       CONSTRAINT CHK_ContactEmail_OthFamily CHECK (ContactEmail_OthFamily IN ('Yes', 'No')),\
ContactText_OthFamily       NVARCHAR       CONSTRAINT CHK_ContactText_OthFamily CHECK (ContactText_OthFamily IN ('Yes', 'No')),\
ContactVideo_OthFamily      NVARCHAR       CONSTRAINT CHK_ContactVideo_OthFamily CHECK (ContactVideo_OthFamily IN ('Yes', 'No')),\
ContactSocMedia_OthFamily   NVARCHAR       CONSTRAINT CHK_ContactSocMedia_OthFamily CHECK (ContactSocMedia_OthFamily IN ('Yes', 'No')),\
ChangeContact_OthFamily     NVARCHAR       CONSTRAINT CHK_ChangeContact_OthFamily CHECK (ChangeContact_OthFamily IN ('Remained about the same', 'Increased', 'Decreased')),\
ChangeInPerson_OthFamily    NVARCHAR       CONSTRAINT CHK_ChangeInPerson_OthFamily CHECK (ChangeInPerson_OthFamily IN ('Remained about the same', 'Increased', 'Decreased')),\
\
ContactInPerson_Friends     NVARCHAR       CONSTRAINT CHK_ContactInPerson_Friends CHECK (ContactInPerson_Friends IN ('Yes', 'No')),\
ContactPhone_Friends        NVARCHAR       CONSTRAINT CHK_ContactPhone_Friends CHECK (ContactPhone_Friends IN ('Yes', 'No')),\
ContactEmail_Friends        NVARCHAR       CONSTRAINT CHK_ContactEmail_Friends CHECK (ContactEmail_Friends IN ('Yes', 'No')),\
ContactText_Friends         NVARCHAR       CONSTRAINT CHK_ContactText_Friends CHECK (ContactText_Friends IN ('Yes', 'No')),\
ContactVideo_Friends        NVARCHAR       CONSTRAINT CHK_ContactVideo_Friends CHECK (ContactVideo_Friends IN ('Yes', 'No')),\
ContactSocMedia_Friends     NVARCHAR       CONSTRAINT CHK_ContactSocMedia_Friends CHECK (ContactSocMedia_Friends IN ('Yes', 'No')),\
ChangeContact_Friends       NVARCHAR       CONSTRAINT CHK_ChangeContact_Friends CHECK (ChangeContact_Friends IN ('Remained about the same', 'Increased', 'Decreased')),\
ChangeInPerson_Friends      NVARCHAR       CONSTRAINT CHK_ChangeInPerson_Friends CHECK (ChangeInPerson_Friends IN ('Remained about the same', 'Increased', 'Decreased')),\
\
\
\
/*** Loneliness ***/ \
Lonely                 NVARCHAR       CONSTRAINT CHK_Lonely CHECK (Lonely IN ('Hardly ever or never', 'Some of the time', 'Often')),\
ChangeLonely           NVARCHAR       CONSTRAINT CHK_ChangeLonely CHECK (ChangeLonely IN ('Increased', 'Remained about the same', 'Decreased')),\
\
\
\
/*** Covid-19 Experiences ***/ \
HowConcerned           NVARCHAR       CONSTRAINT CHK_HowConcerned CHECK (HowConcerned IN \
                                            ('Not at all concerned', 'A little concerned', 'Moderately concerned', \
                                             'Very concerned', 'Extremely concerned')),\
Isolating              NVARCHAR       CONSTRAINT CHK_Isolating CHECK (Isolating IN ('All of the time', 'Most of the time', 'Some of the time', 'None of the time')),\
ChangeIsolating        NVARCHAR       CONSTRAINT CHK_ChangeIsolating CHECK (ChangeIsolating IN ('Increased', 'Remained about the same', 'Decreased')),\
\
\
\
/*** Health Behaviors ***/ \
DaysExercise           INTEGER        CONSTRAINT CHK_DaysExercise CHECK (DaysExercise >= 0 AND DaysExercise <= 7),\
ChangeExercise         NVARCHAR       CONSTRAINT CHK_ChangeExercise CHECK (ChangeExercise IN ('Increased', 'Remained about the same', 'Decreased')),\
DaysAlcohol            INTEGER        CONSTRAINT CHK_DaysAlcohol CHECK (DaysAlcohol >= 0 AND DaysAlcohol <= 7),\
ChangeAlcohol          NVARCHAR       CONSTRAINT CHK_ChangeAlcohol CHECK (ChangeAlcohol IN ('Increased', 'Remained about the same', 'Decreased')),\
DifficultySleep        NVARCHAR       CONSTRAINT CHK_DifficultySleep CHECK (DifficultySleep IN ('None', 'Mild', 'Moderate', 'Severe', 'Extreme')),\
ChangeSleep            NVARCHAR       CONSTRAINT CHK_ChangeSleep CHECK (ChangeSleep IN ('Improved', 'Remained about the same', 'Worsened')),\
\
\
\
/*** Wellbeing ***/ \
Disability             NVARCHAR       CONSTRAINT CHK_Disability CHECK (Disability IN ('Yes', 'No')),\
LimitActivities        NVARCHAR       CONSTRAINT CHK_LimitActivities CHECK (LimitActivities IN ('Yes', 'No')),\
PhysicalHealth         NVARCHAR       CONSTRAINT CHK_PhysicalHealth CHECK (PhysicalHealth IN ('Excellent', 'Very good', 'Good', 'Fair', 'Poor')),\
ChangePhysical         NVARCHAR       CONSTRAINT CHK_ChangePhysical CHECK (ChangePhysical IN ('Better', 'About the same', 'Worse')),\
MentalHealth           NVARCHAR       CONSTRAINT CHK_MentalHealth CHECK (MentalHealth IN ('Excellent', 'Very good', 'Good', 'Fair', 'Poor')),\
ChangeMental           NVARCHAR       CONSTRAINT CHK_ChangeMental CHECK (ChangeMental IN ('Better', 'About the same', 'Worse')),\
\
\
\
/*** Rotary Involvement ***/ \
RotaryMember           NVARCHAR       NOT NULL CONSTRAINT CHK_RotaryMember CHECK (RotaryMember IN ('Yes')),\
/*** Null vales are not allowed, because RotaryMember is used to define the analytical sample. ***/ \
RotaryInvolvement      NVARCHAR       CONSTRAINT CHK_RotaryInvolvement CHECK (RotaryInvolvement IN ('Yes', 'No')),\
RotaryChange           NVARCHAR       CONSTRAINT CHK_RotaryChange CHECK (RotaryChange IN ('Increased', 'Remained about the same', 'Decreased')),\
RotaryChallenges       TEXT,\
\
\
\
/*** Rotary Club Activities ***/ \
CovidAct               TEXT,\
OthAct                 TEXT,\
\
\
\
/*** Rotary Club Impact ***/ \
ImpactOnMeetings       NVARCHAR       CONSTRAINT CHK_ImpactOnMeetings CHECK (ImpactOnMeetings IN \
                                            ('No impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted')),\
ImpactOnPartnerships   NVARCHAR       CONSTRAINT CHK_ImpactOnPartnerships CHECK (ImpactOnPartnerships IN \
                                            ('No impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted')),\
ImpactOnFinances       NVARCHAR       CONSTRAINT CHK_ImpactOnFinances CHECK (ImpactOnFinances IN \
                                            ('No impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted')),\
ImpactOnMembership     NVARCHAR       CONSTRAINT CHK_ImpactOnMembership CHECK (ImpactOnMembership IN \
                                            ('No impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted')),\
OthImpact              TEXT,\
\
\
\
/*** Rotary Club Response ***/ \
RotaryResponse         TEXT,\
\
\
\
/*** Time and Financial Contributions ***/ \
Contrib_Charitable          NVARCHAR        CONSTRAINT CHK_Contrib_Charitable CHECK (Contrib_Charitable IN \
                                                  ('No contribution', 'Contribution of time', 'Financial contribution', 'Both')),\
Contrib_Religious           NVARCHAR        CONSTRAINT CHK_Contrib_Religious CHECK (Contrib_Religious IN \
                                                  ('No contribution', 'Contribution of time', 'Financial contribution', 'Both')),\
Contrib_Other               NVARCHAR        CONSTRAINT CHK_Contrib_Other CHECK (Contrib_Other IN \
                                                  ('No contribution', 'Contribution of time', 'Financial contribution', 'Both')),\
ContribChange_Charitable    NVARCHAR        CONSTRAINT CHK_ContribChange_Charitable CHECK (ContribChange_Charitable IN \
                                                  ('Increased', 'Remained about the same', 'Decreased')),\
ContribChange_Religious     NVARCHAR        CONSTRAINT CHK_ContribChange_Religious CHECK (ContribChange_Religious IN \
                                                  ('Increased', 'Remained about the same', 'Decreased')),\
ContribToCovid              NVARCHAR        CONSTRAINT CHK_ContribToCovid CHECK (ContribToCovid IN ('Yes', 'In part', 'No')),\
\
\
\
/*** Location ***/ \
Latitude               FLOAT,\
Longitude              FLOAT,\
\
\
\
/*** TABLE CONSTRAINTS ***/ \
PRIMARY KEY (ClubID, IndvID),\
FOREIGN KEY (ClubID)\
        REFERENCES ClubLvl (ClubID)\
        ON DELETE CASCADE\
        ON UPDATE CASCADE)")

# %% [markdown]
# ### Information About Each Table

# %% [markdown]
# PRAGMA table_info() provides the following information about each column as a list of tuples, with one tuple per column:\
# -Column index\
# -Column name\
# -Column type, as given\
# -Has a NOT NULL constraint\
# -DEFAULT value\
# -Is part of the PRIMARY KEY

# %% [markdown]
# ### ClubLvl Table Info

# %%
cursor.execute("PRAGMA table_info(ClubLvl)")

# %%
ClubLvl_info = cursor.fetchall()

# %%
ClubLvl_info = pd.DataFrame(data = ClubLvl_info, columns = ['col_index', 'col_name', 'col_type', 'not_null', 'default_value', 'primary_key'])

# %%
ClubLvl_info.drop('col_index', axis=1, inplace=True)

# %%
ClubLvl_info
# Out:
#      col_name        col_type  not_null default_value  primary_key
# 0      ClubID         INTEGER         0          None            1
# 1   ClubNameR        NVARCHAR         0          None            0
# 2      DistID         INTEGER         0          None            0
# 3    DistName        NVARCHAR         0          None            0
# 4  ClubSample         INTEGER         0          None            0
# 5  ClubWeight  DECIMAL(18,18)         0          None            0

# %% [markdown]
# ### IndvLvl Table Info

# %%
cursor.execute("PRAGMA table_info(IndvLvl)")

# %%
IndvLvl_info = cursor.fetchall()

# %%
IndvLvl_info = pd.DataFrame(data = IndvLvl_info, columns = ['col_index', 'col_name', 'col_type', 'not_null', 'default_value', 'primary_key'])

# %%
IndvLvl_info.drop('col_index', axis=1, inplace=True)

# %%
pd.set_option("max_rows", None)

# %%
IndvLvl_info
# Out:
#                      col_name  col_type  not_null default_value  primary_key
# 0                      ClubID   INTEGER         0          None            1
# 1                      IndvID   INTEGER         0          None            2
# 2                     Country  NVARCHAR         1          None            0
# 3                    PostCode  NVARCHAR         0          None            0
# 4                      Gender  NVARCHAR         0          None            0
# 5                         Age  NVARCHAR         0          None            0
# 6                   BirthYear   INTEGER         0          None            0
# 7                  BirthMonth  NVARCHAR         0          None            0
# 8              ActivityStatus  NVARCHAR         0          None            0
# 9           ResidentialStatus  NVARCHAR         0          None            0
# 10            OwnershipStatus  NVARCHAR         0          None            0
# ...

# %% [markdown]
# ### Inserting data into table ClubLvl

# %%
cursor.execute("INSERT INTO ClubLvl \
(ClubID, ClubNameR) \
VALUES \
(101005, 'Aberdeen Deeside'),\
(101011, 'Alford & District'),\
(101019, 'Blairgowrie'),\
(101022, 'Broughty Ferry'),\
(101030, 'Claverhouse'),\
(101034, 'Dingwall'),\
(101036, 'Dunfermline'),\
(101038, 'East Sutherland'),\
(101039, 'Elgin'),\
(101044, 'Fraserburgh'),\
(101051, 'Inverness Loch Ness'),\
(101052, 'Inverness Riverside'),\
(101053, 'Inverurie'),\
(101058, 'Kintore, Kemnay & District'),\
(101061, 'Kirriemuir'),\
(101063, 'Leven'),\
(124054, 'Stort Valley'),\
(124055, 'Thorpe Bay'),\
(126004, 'Amwell'),\
(126019, 'Chesham'),\
(126025, 'Hatfield'),\
(126030, 'Hitchin Priory'),\
(126046, 'Royston'),\
(126049, 'St Albans Priory'),\
(128505, 'Bolton Daybreak'),\
(128519, 'Frodsham & Helsby'),\
(128559, 'Tottington & Bury West'),\
(128562, 'Warrington'),\
(128567, 'Worsley'),\
(999999, NULL)")

# %% [markdown]
# ### Saving ClubLvl table to DataFrame

# %%
ClubLvl = pd.read_sql("SELECT * FROM ClubLvl", connection)

# %%
ClubLvl.head(50)
# Out:
#     ClubID                   ClubNameR DistID DistName ClubSample ClubWeight
# 0   101005            Aberdeen Deeside   None     None       None       None
# 1   101011           Alford & District   None     None       None       None
# 2   101019                 Blairgowrie   None     None       None       None
# 3   101022              Broughty Ferry   None     None       None       None
# 4   101030                 Claverhouse   None     None       None       None
# 5   101034                    Dingwall   None     None       None       None
# 6   101036                 Dunfermline   None     None       None       None
# 7   101038             East Sutherland   None     None       None       None
# 8   101039                       Elgin   None     None       None       None
# 9   101044                 Fraserburgh   None     None       None       None
# 10  101051         Inverness Loch Ness   None     None       None       None
# ...

# %%
ClubLvl.to_pickle(r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\SavedDataFiles\ClubLvl.pkl")

# %%
ClubLvl.to_csv(r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\SavedDataFiles\ClubLvl.csv")

# %%
pyreadstat.write_sav(ClubLvl, r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\SavedDataFiles\ClubLvl.sav")

# %% [markdown]
# ### Inserting data into table IndvLvl

# %%
cursor.execute("INSERT INTO IndvLvl \
(ClubID, IndvID, Country, PostCode, \
Gender, Age, BirthYear, BirthMonth, \
ActivityStatus, ResidentialStatus, OwnershipStatus, LiveAlone, Ethnicity, Education, Religion, \
PersonalChallenges, \
MaritalStat, ChildNum, ChildCoResNum_1, ChildCoResNum_2, ChildCoResNum_3, ChildCoResNum_4, ChildCoResNum_5, SibsNum, HasOthFamily, HasFriends, \
ContactInPerson_Child, ContactPhone_Child, ContactEmail_Child, ContactText_Child, ContactVideo_Child, ContactSocMedia_Child, ChangeContact_Child, ChangeInPerson_Child, \
ContactInPerson_Sibs, ContactPhone_Sibs, ContactEmail_Sibs, ContactText_Sibs, ContactVideo_Sibs, ContactSocMedia_Sibs, ChangeContact_Sibs, ChangeInPerson_Sibs, \
ContactInPerson_OthFamily, ContactPhone_OthFamily, ContactEmail_OthFamily, ContactText_OthFamily, ContactVideo_OthFamily, ContactSocMedia_OthFamily, ChangeContact_OthFamily, ChangeInPerson_OthFamily, \
ContactInPerson_Friends, ContactPhone_Friends, ContactEmail_Friends, ContactText_Friends, ContactVideo_Friends, ContactSocMedia_Friends, ChangeContact_Friends, ChangeInPerson_Friends, \
Lonely, ChangeLonely, HowConcerned, Isolating, ChangeIsolating, \
DaysExercise, ChangeExercise, DaysAlcohol, ChangeAlcohol, DifficultySleep, ChangeSleep, \
Disability, LimitActivities, PhysicalHealth, ChangePhysical, MentalHealth, ChangeMental, \
RotaryMember, RotaryInvolvement, RotaryChange, RotaryChallenges, CovidAct, OthAct, \
ImpactOnMeetings, ImpactOnPartnerships, ImpactOnFinances, ImpactOnMembership, OthImpact, RotaryResponse, \
Contrib_Charitable, Contrib_Religious, Contrib_Other, \
ContribChange_Charitable, ContribChange_Religious, ContribToCovid, \
Latitude, Longitude) \
VALUES \
(101005, 1, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', '
 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 0, 'Remained about the same', 'Severe', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, NULL, 'Increased', NULL, 'Yes', 54.7698974609375, -1.55900573730468), \
(104002, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, NULL, NULL, 'Financial contribution', NULL, NULL, 'In part', 53.577392578125, -0.740798950195312), \
(104004, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, '1', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Decreased', 7, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'Yes', 53.6820983886718, -0.673004150390625), \
(104015, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Increased', 4, 'Decreased', 'None', 'Improved', 'Yes', 'No', 'Excellent', 'Better', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'In part', 53.6788024902343, -0.723098754882812), \
(104015, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Catholic', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 2, 'Remained about the same', 1, 'Decreased', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Both', 'Remained about the same', 'Remained about the same', 'No', 53.6201934814453, -0.48370361328125), \
(104015, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 0, 'Remained about the same', 1, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'Better', 'Yes', 'No', 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'Financial contribution', NULL, NULL, 'Yes', 51.4963989257812, -0.122406005859375), \
(104020, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Other Christian', NULL, 'Married', '5 or more', NULL, NULL, NULL, NULL, '1', '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Increased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Most of the time', 'Remained about the same', 2, 'Decreased', 0, 'Remained about the same', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Contribution of time', 'No contribution', 'No contribution', 'Decreased', NULL, 'In part', 53.4940948486328, -2.08659362792968), \
(104031, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Remained about the same', 'Remained about the same', 'In part', 54.0440979003906, -1.41070556640625), \
(104044, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 3, 'Remained about the same', 4, 'Decreased', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', NULL, 'Contribution of time', 'Remained about the same', NULL, 'In part', 53.7678070068359, -0.300506591796875), \
(104048, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 2, 'Increased', 7, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 53.9367980957031, -1.74679565429687), \
(104049, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Decreased', 4, 'Remained about the same', 'Mild', 'Worsened', 'No', NULL, 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'In part', 51.4875030517578, -0.02459716796875), \
(104049, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Decreased', 6, 'Remained about the same', 2, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', NULL, 'Decreased', NULL, 'In part', 53.8128967285156, -1.79080200195312), \
(104049, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 6, 'Increased', 'None', 'Remained about the same', NULL, NULL, 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Contribution of time', 'Both', 'Increased', 'Increased', 'Yes', 53.9447937011718, -1.87950134277343), \
(104049, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 5, 'Increased', 7, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, NULL, NULL, 'Both', NULL, NULL, 'No', 53.75439453125, -1.76220703125), \
(104050, 1, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Irish', 'Postgraduate/higher degree', 'Catholic', NULL, NULL, 'None', NULL, NULL, NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 3, 'Remained about the same', 'Severe', 'Remained about the same', 'No', NULL, 'Good', 'Better', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'Both', 'Financial contribution', 'Remained about the same', 'Increased', 'No', 53.8542938232421, -1.91650390625), \
(104050, 2, 'England', NULL, 'Female', '65-74 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Moderately concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', NULL, NULL, 'Remained about the same', NULL, 'No', NULL, NULL), \
(104050, 3, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, '2', NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Remained about the same', 0, 'Decreased', 4, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'Yes', 'Poor', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Financial contribution', 'Financial contribution', 'Increased', 'Remained about the same', 'In part', 53.8860931396484, -1.94549560546875), \
(104050, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 3, 'Increased', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Increased', 'Increased', 'Yes', 54.0283050537109, -2.15060424804687), \
(104064, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 5, 'Remained about the same', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 53.764404296875, -1.73359680175781), \
(104064, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'British', 'HNC/HND or equivalent', 'Other Christian', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 4, 'Increased', 5, 'Decreased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', NULL, 'Financial contribution', 'Increased', NULL, 'In part', 53.788101196289, -1.60079956054687), \
(104064, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '5 or more', NULL, NULL, NULL, NULL, 'None', '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 5, 'Increased', 'Severe', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 51.5554046630859, 0.6466064453125), \
(104064, 4, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Increased', 5, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Both', 'Increased', NULL, 'In part', 51.5554046630859, 0.6466064453125), \
(104064, 5, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 4, 'Decreased', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 53.6907958984375, -1.62910461425781), \
(104064, 6, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Increased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Financial contribution', 'Increased', 'Decreased', 'In part', 53.6907958984375, -1.62910461425781), \
(104064, 7, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', NULL, 'Sixth year studies or equivalent', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Often', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', NULL, 'Decreased', 1, NULL, 'None', 'Remained about the same', NULL, NULL, 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'No', 53.7095031738281, -1.49929809570312), \
(104073, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 2, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', 53.8553924560546, -1.5491943359375), \
(104073, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', NULL, 'HNC/HND or equivalent', NULL, NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 6, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 53.831802368164, -1.53579711914062), \
(104077, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 6, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Decreased', NULL, 'In part', 53.4971923828125, -1.18080139160156), \
(104077, 2, 'England', NULL, 'Male', '55-64 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'A little concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Contribution of time', NULL, NULL, 'Remained about the same', NULL, 'Yes', NULL, NULL), \
(104077, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Increased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Increased', 'Increased', 'In part', 53.4403076171875, -0.588302612304687), \
(104077, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 2, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Increased', 'Remained about the same', 'No', 53.6201934814453, -0.48370361328125), \
(104088, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 53.7362976074218, -2.00390625), \
(104097, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 7, 'Decreased', 7, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'No impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Increased', NULL, 'No', 53.9454956054687, -1.11709594726562), \
(104097, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 2, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', 'Increased', 'Yes', 53.9951019287109, -1.16259765625), \
(104098, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Widowed', '1', 'Yes', NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 1, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'No contribution', 'Increased', 'Remained about the same', 'In part', 53.8016967773437, -1.78480529785156), \
(104098, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 4, 'Increased', 0, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Both', NULL, NULL, 'Increased', NULL, 'Yes', 53.9573059082031, -1.08369445800781), \
(104098, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Other Christian', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same',
 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Decreased', NULL, 'In part', 52.2489929199218, 0.0287933349609375), \
(107058, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Remained about the same', 3, 'Decreased', 2, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Increased', 'Increased', 'Yes', 52.585205078125, -0.235992431640625), \
(107061, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Increased', 2, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, NULL, 'Increased', NULL, 'In part', 52.027603149414, -0.731201171875), \
(107075, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'None of the time', 'Remained about the same', 5, 'Increased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.2689056396484, -0.335494995117187), \
(107076, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', NULL, 'First degree', NULL, NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '0', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 53.2738037109375, -2.60870361328125), \
(107076, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Increased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 52.6018981933593, -1.10760498046875), \
(107087, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Divorced', '3', NULL, NULL, 'None', NULL, NULL, '2', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'A little concerned', 'Most of the time', 'Remained about the same', 5, 'Increased', 2, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'Better', 'Poor', 'Better', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, NULL, NULL, 'Both', NULL, NULL, 'In part', 52.7734069824218, -0.816696166992187), \
(108007, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 0, 'Remained about the same', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Worse', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, NULL, NULL, 'Contribution of time', 'Financial contribution', 'Financial contribution', 'Increased', NULL, 'In part', 52.1932067871093, 0.142593383789062), \
(108007, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Decreased', 5, 'Increased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Contribution of time', 'Increased', 'Remained about the same', 'Yes', 52.2241973876953, 0.131500244140625), \
(108007, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Primary or equivalent', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, NULL, NULL, 'No contribution', NULL, NULL, NULL, 52.1932067871093, 0.142593383789062), \
(108007, 4, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Other', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', NULL, NULL, 'Remained about the same', NULL, 'Yes', 52.1932067871093, 0.142593383789062), \
(108007, 5, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Increased', 3, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 51.9275970458984, -0.496795654296875), \
(108008, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 3, 'Increased', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'In part', 52.2599029541015, 0.228805541992187), \
(108008, 2, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 52.1929016113281, 0.125595092773437), \
(108008, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 5, 'Remained about the same', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'No', 52.1932067871093, 0.142593383789062), \
(108008, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 5, 'Remained about the same', 1, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 51.9884033203125, 0.158706665039062), \
(108008, 5, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Catholic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 2, 'Remained about the same', 7, 'Remained about the same', 'Mild', 'Worsened', NULL, NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 52.1932067871093, 0.142593383789062), \
(108008, 6, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, '1', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Excellent', 'Better', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'In part', 57.1558074951171, -2.35740661621093), \
(108013, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Other', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 3, 'Remained about the same', 2, 'Remained about the same', 'Severe', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', NULL, 'Both', 'Remained about the same', NULL, 'In part', 52.3404998779296, 0.993499755859375), \
(108013, 2, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Most of the time', 'Remained about the same', 0, 'Decreased', 2, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'No contribution', 'Remained about the same', 'Remained about the same', 'No', 52.3404998779296, 0.993499755859375), \
(108013, 3, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Increased', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', NULL, 'Remained about the same', 'Remained about the same', 'No', 52.3404998779296, 0.993499755859375), \
(108013, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Other', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'None of the time', 'Remained about the same', 7, 'Remained about the same', 4, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'No', 51.9367065429687, -0.509994506835937), \
(108013, 5, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', NULL, 'Decreased', NULL, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Fair', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Increased', NULL, 'No', 52.3404998779296, 0.993499755859375), \
(108015, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 5, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Both', 'Remained about the same', 'Increased', 'In part', 52.4053039550781, 0.221893310546875), \
(108015, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Other Christian', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'Often', 'Increased', 'Very concerned', 'All of the time', 'Remained about the same', 0, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'No impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Decreased', NULL, 'In part', 52.2265014648437, 0.478302001953125), \
(108018, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 5, 'Increased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Contribution of time', 'Financial contribution', 'Increased', 'Remained about the same', 'Yes', 51.9638061523437, 1.35110473632812), \
(108029, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Increased', 'A little concerned', 'Some of the time', 'Remained about the same', 2, 'Decreased', 1, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Decreased', 'Yes', 52.068603515625, 1.14430236816406), \
(108029, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'Better', 'Excellent', 'Better', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'No contribution', NULL, 'Increased', NULL, 'Yes', 51.3170928955078, -0.023193359375), \
(108029, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Increased', 2, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Decreased', 'Remained about the same', 'In part', 51.7218933105468, 0.481094360351562), \
(108029, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Increased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Increased', 7, 'Remained about the same', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'No impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 52.0435028076171, 1.1842041015625), \
(108029, 5, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 52.0610961914062, 1.1575927734375), \
(108029, 6, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Increased', 1, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 52.0605010986328, 1.23579406738281), \
(108054, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Increased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 0, 'Remained about the same', NULL, NULL, 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'Yes', 52.1325073242187, 0.98980712890625), \
(108054, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Other Christian', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Increased', 1, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 52.1325073242187, 0.98980712890625), \
(108054, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Remained about the same', 7, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'No impact', NULL, 'Yes, mixed impact', NULL, NULL, NULL, 'Contribution of time', 'Financial contribution', NULL, 'Remained about the same', 'Decreased', 'In part', 51.4963989257812, -0.122406005859375), \
(108054, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Poor', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'In part', 52.1325073242187, 0.98980712890625), \
(108062, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 5, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 52.0610961914062, 1.1575927734375), \
(108062, 2, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.0610961914062, 1.1575927734375), \
(108062, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Primary or equivalent', 'Protestant', NULL, 'Living with a partner as if married', '1', 'No', NULL, NULL, NULL, NULL, '2', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'None of the time', 'Remained about the same', 0, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, NULL, 'Financial contribution', NULL, NULL, 'Decreased', 'Yes', 52.5753936767578, 1.09410095214843), \
(108064, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Decreased', 7, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, 'Both', 'Increased', NULL, 'In part', 52.5677947998046, 1.66200256347656), \
(108065, 1, 'England', NULL, 'Other:', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 4, 'Decreased', 5, 'Increased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 52.3404998779296, 0.993499755859375), \
(108065, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Both', 'Both', 'Remained about the same', 'Remained about the same', 'In part', 52.656997680664, 1.206298828125), \
(109009, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 3, 'Increased', 1, 'Remained about the same', NULL, 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'Yes', 51.8813934326171, -2.23739624023437), \
(109021, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 6, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 51.6468048095703, -1.25090026855468), \
(109027, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', NULL, 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'Catholic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'A little concerned', 'Some of the time', 'Decreased', 5, 'Decreased', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Contribution of time', 'Contribution of time', 'Decreased', 'Decreased', 'No', 51.5032958984375, -0.689407348632812), \
(109027, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 7, 'Increased', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'Yes', 51.5177001953125, -0.621505737304687), \
(109027, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 4, 'Increased', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'No impact', 'No impact', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'In part', 51.5032958984375, -0.689407348632812), \
(109027, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Decreased', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Increased', NULL, 'In part', 51.471206665039, -0.942092895507812), \
(109027, 5, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Indian or Indian British', 'Postgraduate/higher degree', 'Other Non-Christian Religion', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Decreased', 'Moderately concerned', 'Most of the time', 'Decreased', 6, 'Increased', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 51.4990997314453, -0.55450439453125), \
(109028, 1, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Looking after home or family', 'A private or family household', NULL, 'No, I live with at least one other person', 'Any Mixed or Multiple ethnic groups', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Increased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'Yes', 51.5032958984375, -0.689407348632812), \
(109028, 2, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Catholic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', 51.4963989257812, -0.122406005859375), \
(109028, 3, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'Yes', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Decreased', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 1, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Contribution of time', NULL, NULL, 'Remained about the same', NULL, 'Yes', NULL, NULL), \
(109032, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Increased', 'A little concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.6484985351562, -0.780105590820312), \
(109032, 2, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Living with a partner as if married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 2, 'Increased', 3, 'Decreased', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Contribution of time', 'Increased', 'Increased', 'In part', 51.4035949707031, -0.761795043945312), \
(109032, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 51.6484985351562, -0.780105590820312), \
(109037, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, '1', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 2, 'Remained about the same', 6, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'No', 51.7095031738281, -1.36140441894531), \
(109039, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', NULL, 'Scottish', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, '2', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Increased', 4, 'Increased', 'Severe', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.3067932128906, 0.7322998046875), \
(109042, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', 'No impact', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Increased', 'Increased', 'Yes', 51.456802368164, -1.04420471191406), \
(109042, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'Catholic', NULL, 'Married', '1', 'Yes', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Increased', 7, 'Remained about the same', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'Financial contribution', 'Contribution of time', 'Remained about the same', 'Increased', 'Yes', 51.4031982421875, -0.920700073242187), \
(109042, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Extremely concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', NULL, NULL, 'Decreased', NULL, 'Yes', NULL, NULL), \
(109042, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 6, 'Decreased', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Financial contribution', 'Increased', 'Remained about the same', 'Yes', 50.9116973876953, -1.53419494628906), \
(109042, 5, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, '2', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Increased', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Decreased', 1, 'Remained about the same', 0, 'Decreased', 'Mild', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.471206665039, -0.942092895507812), \
(109044, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 5, 'Decreased', 1, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'In part', 51.3981018066406, -0.873504638671875), \
(109046, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Increased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 4, 'Decreased', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Remained about the same', 'In part', 51.5554962158203, -0.621200561523437), \
(109049, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Increased', 0, 'Decreased', 0, 'Decreased', 'Mild', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Increased', 'Increased', 'Yes', 51.6484985351562, -0.713592529296875), \
(110002, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Northern Irish', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'In part', 51.4535064697265, -2.59170532226562), \
(110002, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Moderately concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', NULL, NULL, 'Remained about the same', NULL, 'In part', NULL, NULL), \
(110002, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 6, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(110002, 4, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Increased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 5, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(110003, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Decreased', 2, 'Decreased', 0, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(110007, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 5, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', NULL, 'Contribution of time', 'Increased', NULL, 'Yes', 55.9510040283203, -3.19720458984375), \
(110011, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 5, 'Increased', 'Mild', 'Remained about the same', 'Yes', 'No', 'Excellent', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(110011, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'In part', 51.489501953125, -2.50900268554687), \
(110011, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'None of the time', 'Remained about the same', 7, 'Increased', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(110011, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 1, 'Decreased', 6, 'Increased', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 51.475601196289, -2.19850158691406), \
(110019, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 4, 'Increased', 4, 'Increased', 'Mild', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 52.1423950195312, -2.05859375), \
(110020, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 2, 'Remained about the same', 6, 'Increased', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Decreased', NULL, 'Yes', 51.7115020751953, 0.109603881835937), \
(110020, 2, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, NULL, '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 2, 'Remained about the same', 2, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution
 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Other Non-Christian Religion', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Some of the time', 'Increased', 'A little concerned', 'Some of the time', 'Decreased', 3, 'Decreased', 1, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Fair', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 51.3576965332031, 1.06379699707031), \
(112008, 2, 'England', NULL, 'Male', '18-54 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Married', '4', NULL, NULL, NULL, '2', NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 0, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'No impact', 'Yes, positively impacted', NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, NULL, NULL), \
(112008, 3, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Increased', 0, 'Decreased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, NULL, 'Remained about the same', NULL, 'No', 51.392593383789, 1.40460205078125), \
(112018, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, '1', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 2, 'Decreased', 'Severe', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'Financial contribution', 'Both', 'Remained about the same', 'Increased', 'In part', 51.1378936767578, 1.21870422363281), \
(112042, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 5, 'Increased', 4, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.167007446289, 0.238296508789062), \
(112042, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Decreased', 'A little concerned', 'Most of the time', 'Decreased', 3, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 51.1399993896484, 0.898300170898437), \
(112042, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 51.2546997070312, 0.850799560546875), \
(112042, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '1', 'Yes', NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Increased', NULL, 'Yes', 51.2687072753906, 0.578292846679687), \
(112042, 5, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Catholic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Remained about the same', 6, 'Remained about the same', 0, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', NULL, NULL, 'Increased', NULL, 'Yes', 50.9028015136718, 0.399795532226562), \
(112042, 6, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 2, 'Decreased', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', 51.2687072753906, 0.578292846679687), \
(112042, 7, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Unemployed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'Other Christian', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 6, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Increased', NULL, 'Yes', 51.25390625, 0.532699584960937), \
(112044, 1, 'England', NULL, 'Male', NULL, NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', NULL, 'First degree', NULL, NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Remained about the same', 7, 'Remained about the same', 3, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', NULL, NULL, 'Decreased', NULL, 'Yes', 51.3365020751953, 1.41659545898437), \
(112046, 1, 'England', NULL, 'Male', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Increased', 7, 'Increased', 6, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.33349609375, 0.76849365234375), \
(112046, 2, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Other Christian', NULL, 'Living with a partner as if married', '2', NULL, '1', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'A little concerned', 'Some of the time', 'Remained about the same', 3, 'Decreased', 2, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'No', 'Good', 'About the same', 'Poor', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Contribution of time', 'Both', 'Decreased', 'Increased', 'In part', 51.3294982910156, 0.5780029296875), \
(112048, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 5, 'Increased', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'Yes', 50.8551940917968, 0.57159423828125), \
(112064, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'None of the time', 'Remained about the same', 3, 'Increased', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'In part', 51.3639068603515, 0.613998413085937), \
(112064, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Catholic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, NULL, 'Both', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 51.3464050292968, 0.737197875976562), \
(112064, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 6, 'Increased', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'In part', 54.4434967041015, -1.85760498046875), \
(112064, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', NULL, 'Decreased', NULL, NULL, 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Decreased', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 51.3464050292968, 0.737197875976562), \
(112073, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 0, 'Decreased', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'In part', 50.9783935546875, 0.104400634765625), \
(112074, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Irish', 'Highers or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, '1', NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 0, 'Decreased', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'Financial contribution', NULL, 'Decreased', 'Remained about the same', 'In part', 51.2738037109375, 0.497695922851562), \
(112076, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Separated', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Not at all concerned', 'None of the time', 'Remained about the same', 5, 'Decreased', 3, 'Decreased', 'Extreme', 'Worsened', 'No', NULL, 'Very good', 'Worse', 'Poor', 'Worse', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 51.3578948974609, 1.31379699707031), \
(113017, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 7, 'Increased', 'Severe', 'Worsened', 'No', NULL, 'Fair', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.6486053466796, 0.04949951171875), \
(113017, 2, 'England', NULL, 'Female', '75 or more years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Extremely concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', 'Contribution of time', 'Both', 'Remained about the same', 'Remained about the same', 'No', NULL, NULL), \
(113017, 3, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 2, 'Decreased', 6, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 52.9859924316406, -2.50480651855468), \
(113017, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 3, 'Remained about the same', 4, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 51.6486053466796, 0.04949951171875), \
(113033, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Divorced', '1', 'No', NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 3, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.4963989257812, -0.122406005859375), \
(113033, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 2, 'Decreased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Contribution of time', 'Decreased', NULL, 'No', 51.5888061523437, -0.0247039794921875), \
(113040, 1, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Divorced', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Decreased', 1, 'Decreased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Increased', NULL, 'In part', 51.6204071044921, 0.0404052734375), \
(114531, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Very concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', NULL, NULL), \
(114533, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '3', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 4, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'In part', 50.8428955078125, -0.115798950195312), \
(114533, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Increased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 3, 'Increased', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'In part', 51.11669921875, -0.016693115234375), \
(114533, 3, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'British', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'All of the time', 'Decreased', 4, 'Increased', 4, 'Remained about the same', 'Mild', 'Worsened', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, 'Contribution of time', 'Increased', NULL, 'Yes', 51.1430053710937, 0.3218994140625), \
(114533, 4, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Often', 'Increased', 'Very concerned', 'Some of the time', 'Increased', 7, 'Remained about the same', 5, 'Decreased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Decreased', 'Remained about the same', 'No', 51.1325073242187, 0.2633056640625), \
(114533, 5, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 2, 'Increased', 6, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', NULL, 'Increased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', 'Financial contribution', NULL, 'Increased', 'Remained about the same', 'Yes', 51.11669921875, -0.016693115234375), \
(114533, 6, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 7, 'Remained about the same', 1, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Both', 'Increased', NULL, 'In part', 51.3132934570312, 0.0343017578125), \
(114533, 7, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Sixth year studies or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 6, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Increased', 'Remained about the same', 'In part', 51.2738037109375, 0.497695922851562), \
(114537, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 2, 'Increased', 0, 'Remained about the same', 'Mild', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'No contribution', 'Decreased', 'Remained about the same', 'In part', 51.3394012451171, -0.740997314453125), \
(114537, 2, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Divorced', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Decreased', 4, 'Remained about the same', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.3394012451171, -0.740997314453125), \
(114538, 1, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Other Christian', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Increased', 7, 'Decreased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', 'Remained about the same', 'Yes', 51.2144012451171, -0.793594360351562), \
(114538, 2, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'British', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 2, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', NULL, NULL), \
(114545, 1, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other ethnic group', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 4, 'Decreased', 7, 'Remained about the same', 'Extreme', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', NULL, 'In part', 51.3157043457031, -0.535003662109375), \
(114545, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Catholic', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Contribution of time', 'No contribution', 'Decreased', 'Decreased', 'Yes', 51.1817932128906, -0.61309814453125), \
(114547, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Increased', 6, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Remained about the same', 'Decreased', 'No', 51.248306274414, -1.12660217285156), \
(114557, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 1, 'Decreased', 4, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Fair', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'In part', 51.4828033447265, -0.137100219726562), \
(114557, 2, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.3139953613281, -0.34100341796875), \
(114567, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 6, 'Remained about the same', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'No contribution', NULL, 'Both', NULL, NULL, 'In part', 51.3264007568359, -0.101104736328125), \
(114576, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Indian or Indian British', 'First degree', 'Muslim', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 6, 'Increased', 0, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, NULL, 'Decreased', NULL, 'In part', 50.8253021240234, -0.371902465820312), \
(114576, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Catholic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 1, 'Decreased', 'None', 'Remained about the same', NULL, NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Contribution of time', NULL, 'Contribution of time', 'Increased', NULL, 'Yes', 50.8612060546875, -0.119400024414062), \
(114583, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', 5, 'Increased', 2, 'Decreased', 'None', 'Improved', 'No', NULL, 'Good', 'Better', 'Very good', 'Better', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, NULL, 'Increased', NULL, 'Yes', 51.4537048339843, -0.23199462890625), \
(114590, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Catholic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'All of the time', 'Decreased', 2, 'Decreased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Both', 'Remained about the same', 'Decreased', 'Yes', 51.3681945800781, -0.402297973632812), \
(115002, 1, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Decreased', 'Moderately concerned', 'Some of the time', 'Decreased', 1, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 51.6701965332031, -3.20680236816406), \
(115015, 1, 'Wales', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Separated', '2', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 3, 'Increased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Financial contribution', 'Remained about the same', NULL, 'In part', 51.4826965332031, -3.18080139160156), \
(115015, 2, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Most of the time', 'Decreased', 3, 'Remained about the same', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Decreased', NULL, 'In part', 51.52099609375, -3.20370483398437), \
(115015, 3, 'Wales', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 3, 'Decreased', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Contribution of time', 'Increased', NULL, 'Yes', 51.52099609375, -3.20370483398437), \
(115015, 4, 'Wales', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', NULL, NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 6, 'Increased', 4, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'Both', 'Financial contribution', 'Remained about the same', 'Remained about the same', 'In part', 51.5131072998046, -3.15879821777343), \
(115015, 5, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 7, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'In part', 51.7239074707031, -3.24729919433593), \
(115015, 6, 'Wales', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', NULL, 'Increased', 'Remained about the same', 'In part', 51.5131072998046, -3.15879821777343), \
(115015, 7, 'Wales', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Welsh', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Increased', 3, 'Increased', 'Mild', 'Improved', 'Yes', 'No', 'Good', 'Better', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.52099609375, -3.20370483398437), \
(115021, 1, 'Wales', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', NULL, 'Remained about the same', 'Remained about the same', 'In part', 51.5054016113281, -3.57940673828125), \
(115021, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Increased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', NULL, 'Both', 'Remained about the same', NULL, 'Yes', 51.5054016113281, -3.57940673828125), \
(115021, 3, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Very concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Increased', NULL, 'No', NULL, NULL), \
(115021, 4, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Increased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Both', 'Both', 'Remained about the same', 'Increased', 'In part', 51.5054016113281, -3.57940673828125), \
(115021, 5, 'Wales', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Other Christian', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 1, 'Decreased', 'Mild', 'Remained about the same', 'Yes', 'No', 'Good', 'Better', 'Excellent', 'Better', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Both', 'Decreased', 'Decreased', 'Yes', 51.6309967041015, -3.47740173339843), \
(115021, 6, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Most of the time', 'Decreased', 7, 'Increased', 2, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Excellent', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'Both', 'Financial contribution', 'Increased', 'Remained about the same', 'In part', 51.6591033935546, -3.59910583496093), \
(115030, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'HNC/HND or equivalent', 'Catholic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 0, 'Decreased', 1, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Poor', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'No contribution', 'No contribution', 'Contribution of time', NULL, NULL, 'In part', 52.373794555664, -2.59840393066406), \
(115030, 2, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 1, 'Decreased', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 52.2330932617187, -2.77259826660156), \
(115049, 1, 'Wales', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'Welsh', 'Postgraduate/higher degree', 'Protestant', NULL, 'Widowed', '1', 'No', NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 51.5054016113281, -3.57940673828125), \
(115049, 2, 'Wales', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 5, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Increased', 'In part', 51.5223999023437, -3.52130126953125), \
(115049, 3, 'Wales', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Widowed', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Often', 'Increased', 'Very concerned', 'Most of the time', 'Remained about the same', 3, 'Decreased', 0, 'Decreased', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'No contribution', 'Financial contribution', 'Increased', NULL, 'In part',
 1, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', NULL, NULL, 'Married', '2', NULL, '2', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'None of the time', 'Remained about the same', 3, 'Decreased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', NULL, 'Both', 'Increased', NULL, 'Yes', 52.58740234375, -2.13800048828125), \
(122003, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Increased', NULL, 'In part', 52.9452972412109, -1.49530029296875), \
(122007, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Increased', 6, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'Better', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', 'Increased', 'In part', 52.9044036865234, -1.23260498046875), \
(122007, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 3, 'Decreased', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'In part', 52.9537963867187, -1.1571044921875), \
(122007, 3, 'England', NULL, 'Male', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'Yes', 'English', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Remained about the same', 2, 'Decreased', 5, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Both', 'Decreased', 'Remained about the same', 'In part', 52.8995971679687, -1.27139282226562), \
(122027, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 0, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'In part', 53.4907073974609, -1.42539978027343), \
(122029, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Both', 'Both', 'Both', 'Remained about the same', 'Increased', 'Yes', 53.5650939941406, -0.637496948242187), \
(122029, 2, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Divorced', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 1, 'Decreased', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'In part', 53.4364929199218, -1.35400390625), \
(122029, 3, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Decreased', 4, 'Remained about the same', 'Severe', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Remained about the same', 'Increased', 'Yes', 53.50390625, -1.02169799804687), \
(122029, 4, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Decreased', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 51.4963989257812, -0.122406005859375), \
(122039, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Increased', 3, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Increased', 'Remained about the same', 'Yes', 53.1658935546875, -1.2113037109375), \
(122053, 1, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Separated', '2', NULL, '2', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 4, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 53.2917938232421, -0.936798095703125), \
(122057, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, '1', NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Decreased', 3, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 51.9221954345703, -2.0509033203125), \
(122057, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 4, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Increased', NULL, 'In part', 53.1190948486328, -0.767898559570312), \
(122064, 1, 'England', NULL, 'Female', '55-64 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Very concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Increased', NULL, 'Yes', NULL, NULL), \
(122064, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Increased', 7, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, NULL, 'Decreased', NULL, 'In part', 51.4203033447265, -0.11749267578125), \
(122064, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 5, 'Increased', 7, 'Decreased', 'None', 'Improved', 'Yes', 'Yes', 'Fair', 'Better', 'Fair', 'Better', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 53.8742980957031, -3.02330017089843), \
(122064, 4, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Decreased', 3, 'Decreased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Decreased', NULL, 'Yes', 51.6076965332031, -0.166000366210937), \
(122064, 5, 'England', NULL, 'Male', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Catholic', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 4, 'Decreased', 3, 'Decreased', 'Mild', 'Improved', 'No', NULL, 'Very good', 'About the same', 'Very good', 'Better', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Increased', 'Increased', 'Yes', 51.4963989257812, -0.122406005859375), \
(122064, 6, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Remained about the same', 2, 'Decreased', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, 'Both', 'Increased', NULL, 'Yes', 53.1130981445312, -1.6593017578125), \
(122064, 7, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Decreased', 4, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'Better', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'In part', 53.2126007080078, -1.18209838867187), \
(122064, 8, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Increased', 2, 'Decreased', 7, 'Increased', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, NULL, 'Financial contribution', 'Financial contribution', NULL, 'Remained about the same', 'In part', 53.1130981445312, -1.6593017578125), \
(123004, 1, 'Scotland', NULL, 'Female', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Highers or equivalent', 'Catholic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 6, 'Decreased', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'Yes', 55.8318939208984, -4.43220520019531), \
(123011, 1, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'Yes', 'British', 'O level/O grade or equivalent', 'Protestant', NULL, 'Separated', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Increased', 3, 'Decreased', 1, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Decreased', NULL, 'In part', 55.0933074951171, -3.55900573730468), \
(123023, 1, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Jewish', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 5, 'Remained about the same', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 52.6051025390625, -1.6748046875), \
(123025, 1, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Increased', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'Financial contribution', 'Contribution of time', 'Increased', 'Remained about the same', 'In part', 55.8318939208984, -4.43220520019531), \
(123025, 2, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Unemployed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 7, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, NULL, NULL, 'Both', NULL, NULL, 'Yes', 55.8307952880859, -4.49099731445312), \
(123025, 3, 'Scotland', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 7, 'Remained about the same', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'Better', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Both', 'Increased', 'Remained about the same', 'In part', 55.8392944335937, -4.28919982910156), \
(123028, 1, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Decreased', 1, 'Decreased', 4, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Excellent', 'Better', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'Yes', 56.0915985107421, -4.7803955078125), \
(123028, 2, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Increased', 'Yes', 53.7666931152343, -1.81669616699218), \
(123032, 1, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Decreased', 6, 'Remained about the same', 0, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'Financial contribution', NULL, 'Remained about the same', 'Remained about the same', 'Yes', 55.8802947998046, -4.30549621582031), \
(123032, 2, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Socially rented', 'Yes', 'Scottish', 'Highers or equivalent', 'Protestant', NULL, 'Divorced', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Remained about the same', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'No impact', 'Yes, negatively impacted', 'No impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', NULL, 'Remained about the same', NULL, 'In part', 55.8802947998046, -4.30549621582031), \
(123032, 3, 'Scotland', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Increased', 'Very concerned', 'All of the time', 'Decreased', 7, 'Decreased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 55.940200805664, -4.16050720214843), \
(123032, 4, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', 'Financial contribution', 'No contribution', 'Decreased', 'Decreased', 'In part', 55.8670043945312, -4.26210021972656), \
(123039, 1, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Increased', 7, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'Contribution of time', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'In part', 56.4521026611328, -5.57139587402343), \
(124009, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Extremely concerned', 'Some of the time', 'Decreased', 1, 'Decreased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 51.6513061523437, 0.318695068359375), \
(124009, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Both', NULL, NULL, 'Increased', NULL, 'Yes', 51.6047058105468, 0.407699584960937), \
(124009, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 3, 'Remained about the same', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'Contribution of time', NULL, NULL, 'No', 51.6513061523437, 0.318695068359375), \
(124016, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Often', 'Increased', 'Moderately concerned', 'Some of the time', 'Remained about the same', 0, 'Decreased', 0, 'Remained about the same', 'Severe', 'Worsened', 'No', NULL, 'Good', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'In part', 51.4963989257812, -0.122406005859375), \
(124016, 2, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 3, 'Remained about the same', 0, 'Remained about the same', 'Severe', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Increased', NULL, 'In part', 51.446304321289, 0.32550048828125), \
(124016, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Remained about the same', 2, 'Decreased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Both', 'Both', 'Decreased', 'Increased', 'In part', 51.4963989257812, -0.122406005859375), \
(124023, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Increased', 4, 'Remained about the same', 1, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'In part', 51.8372955322265, 0.817398071289062), \
(124023, 2, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, '2', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 2, 'Decreased', 1, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 51.8872985839843, 0.863800048828125), \
(124023, 3, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Decreased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Increased', NULL, 'In part', 51.9049072265625, 0.918594360351562), \
(124023, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Not at all concerned', 'None of the time', 'Remained about the same', 6, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', NULL, NULL, NULL, NULL, 51.9049072265625, 0.918594360351562), \
(124023, 5, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 6, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'No impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Increased', 'Increased', 'In part', 51.4963989257812, -0.122406005859375), \
(124034, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Remained about the same', 2, 'Decreased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Contribution of time', 'Contribution of time', 'Contribution of time', 'Increased', 'Remained about the same', 'In part', 53.5417022705078, -2.11849975585937), \
(124040, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', NULL, 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 51.7245025634765, 0.589492797851562), \
(124040, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Widowed', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Increased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'In part', 52.1423950195312, -2.05859375), \
(124040, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'O level/O grade or equivalent', 'Other Christian', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Increased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Increased', 'Very concerned', 'Most of the time', 'Decreased', 6, 'Increased', 4, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Both', NULL, NULL, 'Remained about the same', NULL, 'Yes', 52.0601043701171, 0.61199951171875), \
(124054, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Increased', 7, 'Increased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Remained about the same', 'In part', 51.4830932617187, -0.164596557617187), \
(124055, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 3, 'Increased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Both', 'Remained about the same', 'Remained about the same', 'In part', 51.539306640625, 0.715194702148437), \
(126004, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Decreased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'No', 51.8209075927734, -0.0133056640625), \
(126004, 2, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 1, 'Remained about the same', 'None', 'Remained about the same', NULL, NULL, 'Very good', 'Better', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'In part', 51.836196899414, -0.268203735351562), \
(126019, 1, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 5, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Contribution of time', 'Financial contribution', 'Financial contribution', 'Increased', 'Decreased', 'Yes', 55.9409027099609, -3.29389953613281), \
(126025, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 6, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'In part', 51.8126068115234, -0.199295043945312), \
(126030, 1, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Increased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 7, 'Remained about the same', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Increased', NULL, 'In part', 51.9053955078125, -0.293701171875), \
(126046, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Decreased', 7, 'Remained about the same', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'Financial contribution', 'Both', 'Increased', 'Decreased', 'Yes', 52.0805053710937, -0.101394653320312), \
(126046, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 5, 'Decreased', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.0805053710937, -0.101394653320312), \
(126046, 3, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', NULL, 'Remained about the same', 7, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'No', 52.0805053710937, -0.101394653320312), \
(126046, 4, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Extremely concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, NULL, 'Contribution of time', 'Contribution of time', NULL, 'Remained about the same', 'In part', 52.2241973876953, 0.131500244140625), \
(126046, 5, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 2, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Contribution of time', 'Increased', NULL, 'In part', 52.0805053710937, -0.101394653320312), \
(126046, 6, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', NULL, 'Very concerned', 'Some of the time', 'Decreased', 7, 'Increased', 3, 'Increased', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'In part', 52.0805053710937, -0.101394653320312), \
(126049, 1, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 2, 'Decreased', 5, 'Decreased', 'Extreme', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'In part', 51.81640625, -0.3572998046875), \
(128505, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'Yes', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Good', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 53.6000061035156, -2.55000305175781), \
(128505, 2, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 1, 'Decreased', 1, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'No impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'In part', 53.1130981445312, -1.6593017578125), \
(128505, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Often', 'Increased', 'Very concerned', 'All of the time', 'Remained about the same', 1, 'Decreased', 1, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Poor', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Both', 'Decreased', NULL, 'In part', 53.5915069580078, -2.39309692382812), \
(128505, 4, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Often', 'Increased', 'Moderately concerned', 'Most of the time', 'Decreased', 0, 'Decreased', 7, 'Remained about the same', 'Severe', 'Worsened', 'No', NULL, 'Fair', 'Worse', 'Poor', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, NULL, 'Financial contribution', 'Contribution of time', NULL, 'Decreased', 'In part', 53.4474029541015, -2.38079833984375), \
(128519, 1, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Increased', 2, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Both', 'Financial contribution', 'No contribution', 'Decreased', 'Remained about the same', 'In part', 53.2779998779296, -2.93490600585937), \
(128519, 2, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Unemployed', 'A private or family household', 'Still being bought', NULL, 'British', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Increased', 5, 'Remained about the same', 4, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'No', 51.4963989257812, -0.122406005859375), \
(128519, 3, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', '
 'Sixth year studies or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 5, 'Remained about the same', 4, 'Increased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'No', 51.4963989257812, -0.122406005859375), \
(999999, 125, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Looking after home or family', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 2, 'Decreased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4452972412109, -0.328506469726562), \
(999999, 126, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Often', 'Increased', 'Moderately concerned', 'Some of the time', 'Increased', 7, 'Decreased', 0, 'Remained about the same', 'Severe', 'Worsened', 'No', NULL, 'Excellent', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'In part', 53.1658935546875, -1.2113037109375), \
(999999, 127, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any Mixed or Multiple ethnic groups', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'Hardly ever or never', 'Decreased', 'Extremely concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(999999, 128, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Financial contribution', 'Increased', 'Increased', 'Yes', 50.7882995605468, -1.89509582519531), \
(999999, 129, 'Scotland', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'Scottish', 'First degree', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Often', 'Increased', 'Very concerned', 'All of the time', 'Remained about the same', 0, 'Decreased', 2, 'Decreased', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Increased', 'Remained about the same', 'Yes', 55.9409027099609, -3.29389953613281), \
(999999, 130, 'England', NULL, 'Male', '75 or more years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Extremely concerned', NULL, NULL, 7, 'Remained about the same', 4, 'Remained about the same', 'None', 'Improved', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', NULL, NULL), \
(999999, 131, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', 'Other Christian', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Increased', 'Moderately concerned', 'Most of the time', 'Decreased', 7, 'Increased', 3, 'Increased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Poor', 'About the same', 'Good', 'About the same', 'Yes', NULL, 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'In part', 51.5032958984375, -0.689407348632812), \
(999999, 132, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Highers or equivalent', 'Catholic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 7, 'Increased', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'Contribution of time', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'Yes', 51.1385955810546, -3.00010681152343), \
(999999, 133, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 4, 'Increased', 3, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'Worse', 'Fair', 'About the same', 'Yes', 'No', 'Increased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Contribution of time', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'No', 55.97509765625, -3.59959411621093), \
(999999, 134, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Often', 'Increased', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 7, NULL, 'Severe', 'Worsened', 'Yes', 'Yes', 'Fair', 'About the same', 'Poor', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', NULL, 'Both', 'Increased', NULL, 'Yes', 50.8493957519531, -1.17770385742187), \
(999999, 135, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 0, 'Decreased', 1, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4409027099609, 0.0984954833984375), \
(999999, 136, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Not at all concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 0, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'No impact', 'No impact', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'No', 51.4963989257812, -0.122406005859375), \
(999999, 137, 'Scotland', NULL, 'Female', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 2, 'Remained about the same', 'Mild', 'Worsened', 'Yes', 'Yes', 'Very good', 'Better', 'Good', 'Better', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Contribution of time', 'Both', 'No contribution', 'Remained about the same', 'Remained about the same', 'In part', 56.1967010498046, -3.13569641113281), \
(999999, 138, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Increased', 4, 'Decreased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'Better', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.8995971679687, -1.27139282226562), \
(999999, 139, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 2, 'Decreased', 3, 'Decreased', 'Mild', 'Worsened', 'Yes', 'Yes', 'Fair', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'Financial contribution', NULL, 'Remained about the same', 'Remained about the same', 'Yes', 50.8460998535156, -0.93170166015625), \
(999999, 140, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Most of the time', 'Increased', 6, 'Decreased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Poor', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 55.9409027099609, -3.29389953613281), \
(999999, 141, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', NULL, 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Divorced', '1', 'No', NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', NULL, 'None of the time', 'Remained about the same', 7, NULL, 0, NULL, 'Severe', NULL, 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 50.4188995361328, -4.064697265625), \
(999999, 142, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Increased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 3, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Excellent', 'Better', 'Good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Remained about the same', 'Remained about the same', 'Yes', 52.0435028076171, 1.1842041015625), \
(999999, 143, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', NULL, NULL, 'In part', 55.8466033935546, -3.19270324707031), \
(999999, 144, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Increased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'Better', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'In part', 51.8813934326171, -2.23739624023437), \
(999999, 145, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Increased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Contribution of time', 'Increased', NULL, 'In part', 51.5666961669921, -0.333297729492187), \
(999999, 146, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 6, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', 'No impact', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Remained about the same', 'Remained about the same', 'In part', 50.8963012695312, -1.04629516601562), \
(999999, 147, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 5, 'Increased', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 53.5335998535156, -1.10459899902343), \
(999999, 148, 'Northern Ireland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Increased', 7, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'Better', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', NULL, NULL, NULL, 'In part', 56.0637054443359, -3.72149658203125), \
(999999, 149, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 2, 'Decreased', 0, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 51.4535064697265, -2.59170532226562), \
(999999, 150, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 7, 'Increased', 5, 'Increased', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'Better', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', 'Increased', 'Yes', 50.9664001464843, -1.33650207519531), \
(999999, 151, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Increased', 'Increased', 'Yes', 55.9989929199218, -2.53819274902343), \
(999999, 152, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'No formal schooling', 'Other Christian', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 2, 'Decreased', 2, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Contribution of time', 'Increased', 'Remained about the same', 'Yes', 51.4963989257812, -0.122406005859375), \
(999999, 153, 'England', NULL, 'Other:', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Increased', 2, 'Decreased', 4, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.
 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'British', 'Sixth year studies or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Divorced', '2', NULL, '1', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Decreased', 5, 'Decreased', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, NULL, 'Remained about the same', NULL, 'In part', 50.9664001464843, -1.33650207519531), \
(999999, 187, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 6, 'Decreased', 4, 'Decreased', 'Severe', 'Worsened', 'Yes', 'Yes', 'Fair', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Decreased', NULL, 'No', 55.9810028076171, -3.37699890136718), \
(999999, 188, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 4, 'Increased', 7, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Financial contribution', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'In part', 53.6235046386718, -2.335205078125), \
(999999, 189, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'None of the time', 'Decreased', 7, 'Remained about the same', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.3229064941406, -2.78390502929687), \
(999999, 190, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Catholic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 2, 'Decreased', 0, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Remained about the same', 'Remained about the same', 'In part', 51.4963989257812, -0.122406005859375), \
(999999, 191, 'England', NULL, 'Male', '18-54 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Moderately concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'No', NULL, NULL), \
(999999, 192, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'English', 'Highers or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Decreased', 'Extremely concerned', 'All of the time', 'Increased', 0, 'Decreased', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', NULL, 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, 'Financial contribution', 'Remained about the same', NULL, 'Yes', 50.7631072998046, -1.29769897460937), \
(999999, 193, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', NULL, 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Remained about the same', 4, 'Increased', 1, 'Remained about the same', 'None', 'Improved', 'Yes', 'No', 'Good', 'About the same', 'Good', 'Better', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.940200805664, -4.16050720214843), \
(999999, 194, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Most of the time', 'Remained about the same', 2, 'Decreased', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Decreased', NULL, 'Yes', 50.9116973876953, -1.53419494628906), \
(999999, 195, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Catholic', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Increased', 'Extremely concerned', 'Most of the time', 'Remained about the same', 5, 'Remained about the same', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', NULL, 'Financial contribution', 'Decreased', NULL, 'In part', 51.5666961669921, -0.333297729492187), \
(999999, 196, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Contribution of time', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 55.6665954589843, -2.86070251464843), \
(999999, 197, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Decreased', 1, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.8392944335937, -4.28919982910156), \
(999999, 198, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Widowed', '4', NULL, NULL, NULL, 'None', NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Often', 'Increased', 'Very concerned', 'Most of the time', 'Remained about the same', 0, 'Decreased', 7, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Decreased', 'Remained about the same', 'No', 51.4060974121093, -2.56269836425781), \
(999999, 199, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Widowed', '3', NULL, NULL, '1', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 3, 'Increased', 2, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'No contribution', 'Remained about the same', NULL, 'Yes', 51.4963989257812, -0.122406005859375), \
(999999, 200, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Other', 'A private or family household', 'Owned outright', 'Yes', 'Northern Irish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Most of the time', 'Decreased', 0, 'Decreased', 3, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'No impact', 'Yes, mixed impact', 'No impact', 'No impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 56.0348052978515, -3.49809265136718), \
(999999, 201, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 3, 'Decreased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', NULL, NULL, 'Decreased', NULL, 'Yes', 50.8963012695312, -1.04629516601562), \
(999999, 202, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'All of the time', 'Remained about the same', 3, 'Increased', 7, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Poor', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.890396118164, -2.87179565429687), \
(999999, 203, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Increased', 6, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.8466033935546, -3.19270324707031), \
(999999, 204, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Living with a partner as if married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 2, 'Increased', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'Both', 'Financial contribution', 'Increased', 'Increased', 'In part', 56.0294952392578, -2.73550415039062), \
(999999, 205, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 7, 'Decreased', 4, 'Increased', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Better', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, NULL, 'Increased', NULL, 'Yes', 50.8034057617187, -1.39570617675781), \
(999999, 206, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'Highers or equivalent', 'Protestant', NULL, 'Widowed', '4', NULL, NULL, NULL, 'None', NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'All of the time', 'Decreased', 0, 'Decreased', 0, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'Yes', 51.6539001464843, -0.08880615234375), \
(999999, 207, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 3, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9510040283203, -3.19720458984375), \
(999999, 208, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Increased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 4, 'Increased', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 53.3022003173828, -2.231201171875), \
(999999, 209, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 52.7563934326171, -2.07269287109375), \
(999999, 210, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Divorced', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Remained about the same', 1, 'Decreased', 2, 'Increased', 'Severe', 'Worsened', 'No', NULL, 'Fair', 'Worse', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Financial contribution', NULL, 'Both', 'Decreased', NULL, 'No', 52.8058013916015, -0.163604736328125), \
(999999, 211, 'Wales', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'Other Christian', NULL, 'Living with a partner as if married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Extremely concerned', 'All of the time', 'Decreased', 5, 'Decreased', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Good', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Both', 'Increased', 'Increased', 'In part', 51.52099609375, -3.20370483398437), \
(999999, 212, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Privately rented', 'Yes', 'Irish', 'First degree', 'Catholic', NULL, 'Separated', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Decreased', 'Very concerned', 'None of the time', 'Decreased', 7, 'Increased', 3, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'Better', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'No impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Increased', 'Yes', 52.9537963867187, -1.1571044921875), \
(999999, 213, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, '1', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 0, 'Remained about the same', 1, 'Decreased', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'No contribution', 'No contribution', 'Financial contribution', NULL, NULL, 'Yes', 55.886001586914, -3.3363037109375), \
(999999, 214, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 7, 'Remained about the same', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.392593383789, 1.40460205078125), \
(999999, 215, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Remained about the same', 3, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Both', 'Both', 'Remained about the same', 'Remained about the same', 'In part', 52.1929016113281, 0.125595092773437), \
(999999, 216, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', NULL, NULL, 0, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Increased', NULL, 'Yes', 50.7850952148437, -1.03889465332031), \
(999999, 217, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 0, 'Decreased', 0, 'Remained about the same', 'Severe', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 50.9378967285156, -0.472000122070312), \
(999999, 218, 'England', NULL, 'Male', '75 or more years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Very concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, NULL, NULL), \
(999999, 219, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Increased', 0, 'Decreased', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'In part', 53.4093933105468, -4.35310363769531), \
(999999, 220, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Widowed', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'Better', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 52.4172973632812, -1.8843994140625), \
(999999, 222, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Often', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 3, 'Remained about the same', 5, 'Increased', 'Severe', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Poor', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Both', 'Financial contribution', 'Both', NULL, NULL, 'Yes', 53.5233001708984, -1.12680053710937), \
(999999, 223, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Looking after home or family', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 4, 'Decreased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Contribution of time', NULL, NULL, 'No', 53.3269958496093, -1.54269409179687), \
(999999, 224, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Increased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 2, 'Remained about the same', 1, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Contribution of time', NULL, NULL, 'No', 57.477798461914, -4.22810363769531), \
(999999, 225, 'England', NULL, 'Male', '65-74 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Very concerned', NULL, NULL, 3, 'Decreased', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Decreased', NULL, 'In part', NULL, NULL), \
(999999, 226, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', NULL, 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Widowed', '1', 'Yes', NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Most of the time', 'Decreased', 3, 'Increased', 1, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.8307952880859, -4.49099731445312), \
(999999, 227, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.8318939208984, -4.43220520019531), \
(999999, 228, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Increased', 'Increased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Increased', 7, 'Decreased', 3, 'Remained about the same', 'Mild', 'Improved', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4963989257812, -0.122406005859375), \
(999999, 229, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 2, 'Remained about the same', 4, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'No contribution', 'No contribution', 'Contribution of time', NULL, NULL, 'In part', 51.0075073242187, -3.10150146484375), \
(999999, 230, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 3, 'Decreased', 5, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Decreased', NULL, 'In part', 50.9141998291015, -1.38800048828125), \
(999999, 231, 'Wales', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'First degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Extremely concerned', 'Most of the time', 'Remained about the same', 2, 'Decreased', 7, 'Increased', 'Severe', 'Worsened', 'No', NULL, 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Remained about the same', 'Remained about the same', 'Yes', 51.6701965332031, -3.20680236816406), \
(999999, 232, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Welsh', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 7, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'No', 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'No', 51.5164031982421, -0.0930023193359375), \
(999999, 233, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 2, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Increased', NULL, 'In part', 51.7384948730468, -2.21940612792968), \
(999999, 234, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Most of the time', 'Increased', 3, 'Decreased', 0, 'Decreased', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Fair', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, NULL, NULL, 'Contribution of time', NULL, NULL, 'No', 51.4566040039062, -0.968002319335937), \
(999999, 235, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Decreased', 7, 'Remained about the same', 5, 'Decreased', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Increased', 'Remained about the same', 'Yes', 53.3376007080078, -1.47709655761718), \
(999999, 236, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Other Non-Christian Religion', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 3, 'Remained about the same', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9409027099609, -3.29389953613281), \
(999999, 237, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', NULL, 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', NULL, 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Financial contribution', NULL, 'Remained about the same', 'Remained about the same', 'In part', 51.4963989257812, -0.122406005859375), \
(999999, 238, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Increased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 4, 'Increased', 7, 'Remained about the same', 'Moderate', 'Worsened', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, NULL, 'Increased', NULL, 'In part', 51.3305053710937, -0.267807006835937), \
(999999, 239, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 3, 'Decreased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 56.0348052978515, -3.49809265136718), \
(999999, 240, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Not at all concerned', 'Most of the time', 'Remained about the same', 5, 'Remained about the same', 2, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Remained about the same', NULL, 'In part', 56.0711059570312, -3.76960754394531), \
(999999, 241, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 0, 'Decreased', 'Moderate', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'No impact', 'No impact', 'No impact', 'No impact', NULL, NULL, 'Both', 'Both', 'Both', 'Decreased', 'Decreased', 'No', 55.6000061035156, -4.61669921875), \
(999999, 242, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', NULL, 'Moderately concerned', 'Some of the time', 'Remained about the same', 6, 'Remained about the same', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 53.508804321289, -1.62739562988281), \
(999999, 243, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Decreased', 6, 'Remained about the same', 0, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Increased', NULL, 'In part', 56.3618011474609, -3.32220458984375), \
(999999, 244, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 4, 'Remained about the same', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, NULL, NULL, 'Financial contribution', NULL, NULL, 'Yes', 50.7886962890625, -1.14750671386718), \
(999999, 245, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Other Christian', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Most of the time', 'Remained about the same', 0, 'Decreased', 1, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Fair', 'Worse', 'Yes', 'No', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.410400390625, -0.304702758789062), \
(999999, 246, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Sixth year studies or equivalent', '
 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'O level/O grade or equivalent', 'Jewish', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Remained about the same', 3, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4745941162109, -0.0924072265625), \
(999999, 277, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 4, 'Increased', 0, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', 'Increased', 'In part', 51.1499938964843, -1.69999694824218), \
(999999, 278, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Increased', 7, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Decreased', NULL, 'No', NULL, NULL), \
(999999, 279, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 5, 'Decreased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9510040283203, -3.19720458984375), \
(999999, 280, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', 5, 'Increased', 3, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'Worse', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'In part', 54.0001068115234, -1.53520202636718), \
(999999, 281, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 5, 'Increased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4963989257812, -0.122406005859375), \
(999999, 282, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Divorced', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 5, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Decreased', NULL, 'No', 50.7554016113281, -1.56660461425781), \
(999999, 283, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 2, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'Both', 'No contribution', 'Increased', 'Remained about the same', 'In part', 53.8542938232421, -1.91650390625), \
(999999, 284, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 1, 'Decreased', 2, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'Better', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Both', 'Remained about the same', NULL, 'In part', 50.7469024658203, -1.75439453125), \
(999999, 285, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 0, 'Decreased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Financial contribution', NULL, NULL, 'Yes', 55.9510040283203, -3.19720458984375), \
(999999, 286, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'English', 'Primary or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Remained about the same', 2, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, NULL, 'No contribution', 'No contribution', 'Contribution of time', NULL, NULL, 'In part', 50.9400939941406, -1.80389404296875), \
(999999, 287, 'Wales', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'HNC/HND or equivalent', 'Other Christian', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Most of the time', 'Increased', 2, 'Decreased', 2, 'Remained about the same', 'Mild', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'No contribution', 'Increased', 'Remained about the same', 'Yes', 51.6965026855468, -4.8887939453125), \
(999999, 288, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Increased', 7, 'Remained about the same', 7, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9488983154296, -3.16319274902343), \
(999999, 289, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 4, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'No', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, NULL, 'Increased', NULL, 'Yes', 52.9875030517578, -2.1802978515625), \
(999999, 290, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Divorced', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Some of the time', 'Increased', 'Extremely concerned', 'Some of the time', 'Decreased', 4, 'Decreased', 1, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 53.544204711914, -1.43049621582031), \
(999999, 291, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Increased', 5, 'Increased', 'Mild', 'Worsened', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, NULL, 'Financial contribution', 'Both', NULL, NULL, 'In part', 53.3202056884765, -2.14129638671875), \
(999999, 292, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Remained about the same', 7, 'Increased', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 56.6903076171875, -2.78880310058593), \
(999999, 293, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, NULL, 'Decreased', NULL, 'No', 50.9051055908203, -1.36549377441406), \
(999999, 294, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Other Christian', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Remained about the same', 5, 'Decreased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Decreased', NULL, 'No', 53.5814971923828, -2.17779541015625), \
(999999, 295, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'Yes', 'Any other White ethnic group', 'HNC/HND or equivalent', 'Catholic', NULL, 'Widowed', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 0, 'Remained about the same', 3, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 51.5538024902343, -0.310195922851562), \
(999999, 296, 'England', NULL, NULL, '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '5 or more', NULL, NULL, NULL, NULL, 'None', '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Increased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Increased', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Increased', NULL, 'Yes', NULL, NULL), \
(999999, 297, 'England', NULL, 'Male', '55-64 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Married', '3', NULL, NULL, '2', NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Moderately concerned', NULL, NULL, 1, 'Decreased', 2, 'Remained about the same', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Fair', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, NULL, NULL, NULL), \
(999999, 298, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Living with a partner as if married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Decreased', 5, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'Worse', 'Fair', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Both', 'Remained about the same', NULL, 'Yes', 51.5576934814453, -1.77670288085937), \
(999999, 299, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Increased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 3, 'Decreased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Remained about the same', 'Remained about the same', 'Yes', 55.9528045654296, -4.0155029296875), \
(999999, 300, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Catholic', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '0', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 7, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'No impact', 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, NULL, 'Remained about the same', NULL, 'In part', 50.8544006347656, -1.00199890136718), \
(999999, 301, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Often', 'Increased', 'Moderately concerned', 'Most of the time', 'Increased', 0, 'Decreased', 5, 'Increased', 'Extreme', 'Worsened', 'Yes', 'Yes', 'Poor', 'Worse', 'Poor', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 51.4963989257812, -0.122406005859375), \
(999999, 302, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 5, 'Increased', 3, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 51.7832946777343, -1.76669311523437), \
(999999, 303, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Privately rented', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 4, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Decreased', NULL, 'In part', 51.4963989257812, -0.122406005859375), \
(999999, 304, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Some of the time', 'Increased', 'Extremely concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 1, 'Remained about the same', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Financial contribution', 'Remained about the same', 'Increased', 'Yes', 50.8695983886718, -1.30909729003906), \
(999999, 305, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Excellent', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.446304321289, 0.32550048828125), \
(999999, 306, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, '1', NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'Most of the time', 'Increased', 7, 'Remained about the same', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9510040283203, -3.19720458984375), \
(999999, 307, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', NULL, 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Remained about the same', NULL, 'Increased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', NULL, NULL), \
(999999, 308, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 0, 'Decreased', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Worse', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'Yes', 52.052001953125, -2.09959411621093), \
(999999, 309, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Most of the time', 'Increased', 7, 'Remained about the same', 0, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'Yes', 55.3999938964843, -1.60000610351562), \
(999999, 310, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 1, 'Decreased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 53.4915924072265, -2.3009033203125), \
(999999, 311, 'England', NULL, 'Female', '65-74 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Extremely concerned', NULL, NULL, 7, 'Remained about the same', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', NULL, NULL, 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Decreased', NULL, 'In part', NULL, NULL), \
(999999, 312, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Decreased', 2, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Remained about the same', NULL, 'No', 56.4701995849609, -3.031005859375), \
(999999, 313, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 2, 'Increased', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 52.2799072265625, -1.94070434570312), \
(999999, 314, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Most of the time', 'Increased', 7, 'Increased', 0, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Contribution of time', 'Contribution of time', 'Contribution of time', 'Decreased', 'Remained about the same', 'In part', 50.8358001708984, -1.06190490722656), \
(999999, 315, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Welsh', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', 'None', NULL, NULL, NULL, NULL, NULL, '2', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Often', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 0, 'Remained about the same', 7, 'Increased', 'Severe', 'Remained about the same', 'Yes', 'Yes', 'Poor', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 50.7886962890625, -1.14750671386718), \
(999999, 316, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Increased', 'Very concerned', 'All of the time', 'Remained about the same', 5, 'Increased', 1, 'Decreased', 'Mild', 'Worsened', 'Yes', 'Yes', 'Fair', 'About the same', 'Fair', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 53.1130981445312, -1.6593017578125), \
(999999, 317, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'HNC/HND or equivalent', NULL, NULL, 'Widowed', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'None of the time', NULL, 4, 'Remained about the same', NULL, 'Increased', 'Moderate', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Decreased', NULL, 'In part', 50.9165954589843, -1.26780700683593), \
(999999, 318, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Living with a partner as if married', '1', 'No', NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 2, 'Decreased', 2, 'Remained about the same', 'Severe', 'Worsened', 'No', NULL, 'Fair', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Increased', NULL, 'In part', 51.4833068847656, 0.149993896484375), \
(999999, 319, 'Wales', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Welsh', 'Postgraduate/higher degree', 'Other Christian', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 3, 'Remained about the same', 6, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', 51.8126983642578, -2.71359252929687), \
(999999, 320, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', NULL, 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, '1', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 5, 'Increased', 5, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, positively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Remained about the same', NULL, 'Yes', 56.0348052978515, -3.49809265136718), \
(999999, 321, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 4, 'Remained about the same', 5, 'Increased', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', 'Remained about the same', NULL, 'In part', 56.4210052490234, -3.47659301757812), \
(999999, 322, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 6, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 53.6347961425781, -2.16960144042968), \
(999999, 323, 'England', NULL, 'Male', '18-54 years', NULL, NULL, 'Self-employed', 'A private or family household', NULL, 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Other Christian', NULL, NULL, '5 or more', NULL, NULL, NULL, NULL, '5 or more', '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Decreased', 'Decreased', 'Often', 'Increased', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Increased', 1, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Both', 'Increased', NULL, 'Yes', 51.0133056640625, -0.332199096679687), \
(999999, 324, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '5 or more', NULL, NULL, NULL, NULL, '1', '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Increased', 'Hardly ever or never', 'Increased', 'Moderately concerned', 'Most of the time', 'Decreased', 6, 'Increased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Financial contribution', 'Increased', 'Increased', 'In part', 50.7895965576171, -2.12489318847656), \
(999999, 325, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'Scottish', 'Highers or equivalent', 'Protestant', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 3, 'Decreased', 1, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9004974365234, -4.45030212402343), \
(999999, 326, 'Scotland', NULL, 'Female', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 6, 'Increased', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'Better', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 57.1452941894531, -2.09449768066406), \
(999999, 327, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Increased', 3, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Both', NULL, NULL, 'Yes', 56.4210052490234, -3.47659301757812), \
(999999, 328, 'England', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Widowed', '1', 'No', NULL, NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Remained about the same', 1, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 53.3368072509765, -1.35470581054687), \
(999999, 329, 'Scotland', NULL, 'Female', '18-54 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Scottish', 'Highers or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '4', NULL, NULL, NULL, '2', NULL, '2', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Decreased', 7, 'Increased', 3, 'Remained about the same', 'Severe', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9425048828125, -3.12930297851562), \
(999999, 330, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Moderately concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', 'Contribution of time', NULL, 'Decreased', 'Decreased', 'In part', NULL, NULL), \
(999999, 331, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'Yes', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Divorced', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Increased', 2, 'Remained about the same', 0, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'Yes', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Decreased', NULL, 'No', 52.58740234375, -2.13800048828125), \
(999999, 332, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'Some of the time', 'Remained about the same', 'Very concerned', 'None of the time', 'Decreased', 3, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'Better', 'Excellent', 'Better', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', NULL, 'Contribution of time', 'Decreased', NULL, 'Yes', 49.45849609375, -2.53959655761718), \
(999999, 333, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Indian or Indian British', 'Postgraduate/higher degree', 'Other Non-Christian Religion', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '4 or more', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Increased', 6, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'No', 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 55.9450073242187, -2.90840148925781), \
(999999, 335, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Widowed', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 2, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'No impact', 'No impact', NULL, NULL, 'Financial contribution', NULL, NULL, 'Remained about the same', NULL, 'Yes', 55.940200805664, -4.16050720214843), \
(999999, 336, 'Scotland', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Increased', 6, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Both', 'Contribution of time', 'Decreased', 'Increased', 'In part', 57.1452941894531, -2.09449768066406), \
(999999, 337, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Other', 'Yes', 'English', 'First degree', 'Catholic', NULL, 'Divorced', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Increased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'None of the time', 'Remained about the same', 1, 'Increased', 3, 'Decreased', 'Mild', 'Worsened', 'Yes', 'No', 'Fair', 'About the same', 'Poor', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, 52.9734954833984, -1.32550048828125), \
(999999, 338, 'Scotland', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Some of the time', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Both', 'Financial contribution', 'No contribution', 'Increased', 'Remained about the same', 'Yes', 55.9205932617187, -2.78819274902343), \
(999999, 339, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Remained about the same', 0, 'Decreased', 0, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 52.4190063476562, -1.99819946289062), \
(999999, 340, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Increased', 3, 'Remained about the same', 2, 'Remained about the same', 'Extreme', 'Worsened', 'No', NULL, 'Very good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, positively impacted', NULL, NULL, 'Both', 'Both', 'Both', 'Increased', 'Remained about the same', 'Yes', 53.3376007080078, -1.47709655761718), \
(999999, 341, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'All of the time', 'Decreased', 1, 'Increased', 3, 'Increased', NULL, NULL, 'No', NULL, 'Good', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 50.9051055908203, -1.36549377441406), \
(999999, 342, 'England', NULL, 'Female', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Jewish', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Extremely concerned', 'Some of the time', 'Decreased', 5, 'Decreased', 6, 'Increased', 'Moderate', 'Remained about the same', 'No', NULL, 'Good', 'Worse', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.6027069091796, -0.1719970703125), \
(999999, 343, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Remained about the same', 2, 'Remained about the same', 1, 'Decreased', 'None', 'Remained about the same', 'No', NULL, 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'In part', 51.0827941894531, -1.35330200195312), \
(999999, 344, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Good', 'Worse', 'Good', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Both', 'No contribution', 'Financial contribution', NULL, NULL, 'Yes', 56.0711059570312, -3.76960754394531), \
(999999, 345, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 3, 'Remained about the same', 0, 'Remained about the same', 'Moderate', 'Worsened', 'Yes', 'No', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Remained about the same', 'In part', 50.6992950439453, -1.91419982910156), \
(999999, 346, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'O level/O grade or equivalent', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Decreased', 7, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Excellent', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Increased', NULL, 'Yes', 52.7982940673828, -1.56520080566406), \
(999999, 347, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', NULL, NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 6, 'Increased', 4, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'No impact', NULL, NULL, 'Financial contribution', 'No contribution', 'No contribution', 'Decreased', NULL, 'No', 50.9116973876953, -1.53419494628906), \
(999999, 348, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'Protestant', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Most of the time', 'Remained about the same', 7, 'Decreased', 3, 'Decreased', 'Severe', 'Worsened', 'Yes', 'No', 'Fair', 'Worse', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', NULL, 'Financial contribution', 'Increased', NULL, 'In part', 52.7050018310546, -2.44320678710937), \
(999999, 349, 'Scotland', NULL, 'Male', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'Yes', 'British', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Separated', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Decreased', 1, 'Decreased', 2, 'Remained about the same', 'Severe', 'Worsened', 'Yes', 'No', 'Poor', 'Worse', 'Fair', 'Worse', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4642944335937, -0.01190185546875), \
(999999, 350, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'First degree', 'Protestant', NULL, 'Separated', '2', NULL, 'None', NULL, NULL, NULL, '2', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 5, 'Remained about the same', 7, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'No impact', 'Yes, mixed impact', NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Decreased', NULL, 'No', 50.7882995605468, -1.89509582519531), \
(999999, 351, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Employed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Indian or Indian British', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Increased', 'Decreased', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Remained about the same', 3, 'Remained about the same', 4, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Very good', 'Better', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, mixed impact', 'No impact', 'Yes, mixed impact', 'No impact', NULL, NULL, 'Both', 'Both', NULL, 'Remained about the same', 'Remained about the same', 'In part', 50.9116973876953, -1.53419494628906), \
(999999, 352, 'Scotland', NULL, 'Female', '55-64 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', 'Yes', 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '3', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Increased', 2, 'Decreased', 4, 'Remained about the same', 'Severe', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4720001220703, -0.22039794921875), \
(999999, 353, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'HNC/HND or equivalent', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Extremely concerned', 'All of the time', 'Decreased', 6, 'Decreased', 6, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Worse', 'Very good', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', NULL, NULL, 'Decreased', NULL, 'Yes', 53.3831024169921, -1.46009826660156), \
(999999, 354, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '1', 'No', NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'Some of the time', 'Decreased', 1, 'Remained about the same', 2, 'Increased', 'None', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Excellent', 'About the same', 'Yes', 'No', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Financial contribution', 'No contribution', 'Financial contribution', 'Decreased', NULL, 'In part', 52.9761962890625, -1.28970336914062), \
(999999, 355, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'All of the time', 'Decreased', 7, 'Decreased', 0, 'Decreased', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.5263061523437, -0.35589599609375), \
(999999, 356, 'England', NULL, 'Male', '55-64 years', NULL, NULL, 'Unemployed', 'A private or family household', 'Still being bought', 'No, I live with at least one other person', 'Indian or Indian British', 'First degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Increased', 'Increased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Often', 'Increased', 'Very concerned', 'Most of the time', 'Remained about the same', 5, 'Decreased', 0, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Good', 'Worse', 'Fair', 'Worse', 'Yes', 'No', 'Remained about the same', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Both', 'Both', 'Financial contribution', 'Increased', 'Increased', 'Yes', 52.5968933105468, -2.18209838867187), \
(999999, 357, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'Catholic', NULL, 'Married', '4', NULL, NULL, NULL, 'None', NULL, '4 or more', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Decreased', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, positively impacted', 'No impact', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'Contribution of time', 'Increased', NULL, 'Yes', 52.12939453125, -1.90480041503906), \
(999999, 358, 'Scotland', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'British', 'First degree', 'Catholic', NULL, 'Widowed', '4', NULL, NULL, NULL, 'None', NULL, '3', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Some of the time', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Remained about the same', 5, 'Remained about the same', 4, 'Remained about the same', 'Moderate', 'Remained about the same', 'No', NULL, 'Very good', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 56.1174011230468, -3.53450012207031), \
(999999, 359, 'England', NULL, 'Male', '18-54 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'Moderately concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No contribution', 'No contribution', 'No contribution', NULL, NULL, NULL, NULL, NULL), \
(999999, 360, 'England', NULL, 'Female', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'Yes', 'English', 'Postgraduate/higher degree', 'Other Christian', NULL, 'Widowed', 'None', NULL, NULL, NULL, NULL, NULL, '3', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'Very concerned', 'Some of the time', 'Decreased', 5, 'Decreased', 2, 'Remained about the same', 'Mild', 'Improved', 'Yes', 'Yes', 'Good', 'Better', 'Very good', 'Better', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', NULL, 'Contribution of time', 'Decreased', NULL, 'No', 51.0401000976562, -0.505294799804687), \
(999999, 361, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '5 or more', NULL, NULL, NULL, NULL, 'None', '3', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 2, 'Decreased', 3, 'Remained about the same', 'Mild', 'Remained about the same', 'No', NULL, 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Both', 'No contribution', 'Both', 'Increased', NULL, 'Yes', 53.1130981445312, -1.6593017578125), \
(999999, 362, 'Scotland', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Scottish', 'First degree', 'Catholic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Increased', 5, 'Remained about the same', 0, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Both', 'Increased', 'Remained about the same', 'Yes', 55.5529022216796, -4.66130065917968), \
(999999, 363, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '3', NULL, NULL, 'None', NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Very concerned', 'Some of the time', 'Decreased', 6, 'Remained about the same', 5, 'Increased', 'Moderate', 'Worsened', 'Yes', 'Yes', 'Good', 'About the same', 'Fair', 'Worse', 'Yes', 'Yes', 'Remained about the same', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'Financial contribution', 'Both', 'Increased', 'Remained about the same', 'In part', 50.9169006347656, -1.4219970703125), \
(999999, 364, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'Any other White ethnic group', 'Postgraduate/higher degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Increased', 'Increased', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Increased', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Increased', 'Increased', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Most of the time', 'Remained about the same', 6, 'Remained about the same', 4, 'Increased', 'Moderate', 'Worsened', 'Yes', 'No', 'Excellent', 'Better', 'Good', 'Worse', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, mixed impact', 'Yes, positively impacted', 'Yes, mixed impact', NULL, NULL, 'Both', 'Both', 'Financial contribution', 'Remained about the same', 'Remained about the same', 'No', 53.1315002441406, -1.29750061035156), \
(999999, 366, 'England', NULL, 'Female', '18-54 years', NULL, NULL, 'Self-employed', 'A private or family household', 'Owned outright', 'Yes', 'Any other ethnic group', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Single', 'None', NULL, NULL, NULL, NULL, NULL, '1', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Increased', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Increased', 'Decreased', 'Some of the time', 'Remained about the same', 'A little concerned', 'Most of the time', 'Decreased', 0, 'Decreased', 1, 'Remained about the same', 'Mild', 'Improved', 'No', NULL, 'Very good', 'Worse', 'Good', 'About the same', 'Yes', 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 51.4409027099609, 0.0984954833984375), \
(999999, 367, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Employed', 'A private or family household', 'Owned outright', NULL, 'English', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Remained about the same', 'Decreased', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Increased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Very concerned', 'Some of the time', 'Remained about the same', 7, 'Increased', 7, 'Remained about the same', 'None', 'Remained about the same', 'No', NULL, 'Excellent', 'Better', 'Very good', 'About the same', 'Yes', 'Yes', 'Increased', NULL, NULL, NULL, 'Yes, mixed impact', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', NULL, 'Financial contribution', 'Increased', NULL, 'Yes', 55.8049926757812, -4.28990173339843), \
(999999, 368, 'England', NULL, 'Male', '65-74 years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', 'No, I live with at least one other person', 'English', 'First degree', 'Protestant', NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '1', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Decreased', 'Decreased', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Some of the time', 'Increased', 'Moderately concerned', 'Some of the time', 'Remained about the same', 4, 'Remained about the same', 6, 'Remained about the same', 'Mild', 'Remained about the same', 'Yes', 'No', 'Very good', 'About the same', 'Very good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Both', 'No contribution', 'No contribution', 'Decreased', NULL, 'Yes', 53.6968994140625, -2.30389404296875), \
(999999, 369, 'Scotland', NULL, 'Female', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'Scottish', 'Postgraduate/higher degree', 'No religion/Atheist/Agnostic', NULL, 'Widowed', '2', NULL, 'None', NULL, NULL, NULL, '2', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Remained about the same', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Remained about the same', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'A little concerned', 'Some of the time', 'Decreased', 7, 'Remained about the same', 5, 'Remained about the same', 'Moderate', 'Remained about the same', 'Yes', 'Yes', 'Good', 'About the same', 'Excellent', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', 'Yes, negatively impacted', NULL, NULL, 'Financial contribution', 'Contribution of time', 'Contribution of time', 'Increased', NULL, 'In part', NULL, NULL), \
(999999, 370, 'England', NULL, 'Male', '75 or more years', NULL, NULL, 'Retired', 'A private or family household', 'Owned outright', NULL, 'English', 'Postgraduate/higher degree', NULL, NULL, 'Married', '2', NULL, 'None', NULL, NULL, NULL, '0', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Decreased', 'Decreased', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Decreased', 'Decreased', 'Hardly ever or never', 'Remained about the same', 'Moderately concerned', 'All of the time', 'Remained about the same', 0, 'Decreased', 1, 'Remained about the same', 'None', 'Remained about the same', 'Yes', 'Yes', 'Fair', 'About the same', 'Good', 'About the same', 'Yes', 'Yes', 'Decreased', NULL, NULL, NULL, 'Yes, positively impacted', 'Yes, positively impacted', 'Yes, mixed impact', 'Yes, mixed impact', NULL, NULL, 'Financial contribution', 'Financial contribution', 'Financial contribution', 'Remained about the same', 'Remained about the same', 'In part', 52.9647979736328, -1.21319580078125), \
(999999, 371, 'England', NULL, 'Female', '18-54 years', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, 'No', 'No', 'No', 'No', 'No', 'No', NULL, NULL, NULL, NULL, 'A little concerned', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Yes', NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, 'Contribution of time', 'No contribution', 'Contribution of time', 'Remained about the same', NULL, 'Yes', NULL, NULL)")

# %% [markdown]
# ### Saving IndvLvl table to DataFrame

# %%
IndvLvl = pd.read_sql("SELECT * FROM IndvLvl", connection)

# %%
IndvLvl.head(50)
# Out:
#     ClubID  IndvID   Country PostCode  Gender               Age BirthYear  \
# 0   101005       1  Scotland     None    Male  75 or more years      None
# 1   101005       2  Scotland     None    Male  75 or more years      None
# 2   101011       1  Scotland     None  Female       18-54 years      None
# 3   101019       1  Scotland     None    Male       55-64 years      None
# 4   101022       1  Scotland     None    Male       65-74 years      None
# 5   101022       2  Scotland     None    Male       65-74 years      None
# 6   101022       3  Scotland     None    Male       65-74 years      None
# 7   101030       1  Scotland     None    Male       65-74 years      None
# 8   101030       2  Scotland     None    Male       65-74 years      None
# 9   101030       3  Scotland     None    Male  75 or more years      None
# 10  101030       4  Scotland     None    Male       65-74 years      None
# 11  101030       5  Scotland     None    Male  75 or more years      None
# ...

# %%
IndvLvl.to_pickle(r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\SavedDataFiles\IndvLvl.pkl")

# %%
IndvLvl.to_csv(r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\SavedDataFiles\IndvLvl.csv")

# %%
pyreadstat.write_sav(IndvLvl, r"C:\Users\Alex\Desktop\Research\RotaryDuringCovid19Survey\DatabaseDesign\SavedDataFiles\IndvLvl.sav")

# %%
connection.close()
